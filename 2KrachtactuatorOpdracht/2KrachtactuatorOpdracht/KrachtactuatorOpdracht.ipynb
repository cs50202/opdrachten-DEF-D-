# %% [markdown]
# # Krachtactuator Ontwerpopdracht
#
# In de eerste 4 weken van het vak DEF-D hebben jullie simulaties gedaan van verschillende opstellingen in de electrostatica. Jullie zijn in week 3.6 bij het vak electromagnetisme doorgegaan met de magnetostatica. Deze opdracht gaat in op het simuleren van deze magnetostatica.
#
# Je werkt bij deze opdracht in teams die wij indelen. Zoek op Brightspace op met wie je samenwerkt en leg via email contact. Maak goede afspraken over hoe je samen gaat werken.
#
# De opdracht bestaat uit de volgende sub-onderdelen:
# 1) Afleiden van een analytische vergelijking
# 2) Criteria opstellen
# 3) Simuleren om de grenzen van jullie ontwerpparameters te bepalen
# 4) Numeriek berekenen van het magneetveld
# 5) Numeriek berekenen van het magneetveld van een solenoide
# 6) Bereken krachtrespons van een kracht actuator
# 7) Beoordeling van de criteria
#
# De opdracht wordt volledig online gedaan, er zullen hiervoor dus ook geen specifieke werkcolleges voor zijn ingeroosterd. Als jullie vragen hebben kunnen jullie die mailen naar het DEF e-mailadres: DEF-TNW@tudelft.nl. Deze opdracht wordt in week 3.9 beoordeeld en herkansingen zijn in week 3.10, zie de studiehandleiding voor details.
#
# Technische Instructies:
# - Download de zip map die op brightspace staat en unzip deze.
# - Creëer een nieuwe branch in je Github repo voor deze opdracht.
# - Plaats de geunzipte map op de juiste plek in jouw branch, zoals in de handleiding op brightspace staat.
# - Nodig je teamgenoot uit als collaborateur op jouw repo.
#
# Onderwijs Instructies:
# - Beantwoord de vragen die in dit notebook voor komen direct in dit notebook.
# - Als je iets moet printen op het scherm als antwoord op een vraag, doe dit op een gestructureerde manier met als dat relevant is de eenheid erbij, zoals je geleerd is bij het Inleidend Practicum.
# - Vermijd 'hardcoden' waar mogelijk.
# - Probeer de voorbeeld code te begrijpen.
# - Op een aantal plekken zijn voorbeelden gegeven of bepaalde numerieke methodes sterk versimpeld. Deze code kunnen reprocuderen is niet een leerdoel van dit vak en zal later in de opleiding voorkomen. Denk hierbij aan het integreren en differentieeren, probeer deze dingen wel te begrijpen.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # DEF-D opdracht 2: Ontwerp een solenoïdale krachtactuator
#
#
# <img align="right" style="margin-left:15px" src="figures\solenoidactuator.png" width="600">
#
#
# In deze ontwerpopdracht ga je een krachtactuator ontwerpen gebaseerd op een solenoïde en een permanente magneet. Deze lineaire krachtactuatoren worden gebruikt om bijvoorbeeld kleppen en afsluiters elektronisch te bedienen. Ook komen ze in vele huidshoudelijk apparaten voor. Hiernaast zie je een plaatje van een krachtactuator van de buitenkant en van de doorsnede. De krachtactuator bestaat uit een solenoïde (spoel), dat is een spiraalvormige stroomkring waar een stroom doorheen loopt. Zoals je weet kan je met een solenoide een redelijk homogeen veld maken als de solenoide lang en smal is. In de solenoïde  zit een cilinder,een zogeheten plunjer, die kan schuiven in de solenoïde. De plunjer is verbonden met het object dat je wilt bewegen. De plunjer kan gemaakt zijn van een magnetisch materiaal met een hoge magnetische permeabiliteit of van een permanente magneet. In dit voorbeeld kiezen we voor een plunjer van magnetiseerbaar materiaal.
#
# Voor het ontwerpen van de actuator gaan we eerst de kracht van de actuator uitrekenen met behulp van analytische theorie. We nemen eerst aan dat de solenoïde ideaal is en leiden daarvoor een analytische vergelijking af. Nadat we een eerste ontwerp hebben gemaakt gebaseerd op de analytische oplossing gaan we simuleren hoe goed onze krachtactuator echt werkt en of we het ontwerp nog kunnen verbeteren. Daar gaan we!
#
# ## Deel 1: afleiden van een analytische vergelijking
#
# Hier onder ze je een detaildoorsnede van de solenoïde. De solenoïde heeft een lengte $L_s$, $N$ wikkelingen, een straal $r_s$ en er loopt een constante stroom $I$ door de draad. De plunjer is een afstand $z_p$ in de solenoide geschoven en moet over een zo groot mogelijke afstand een kracht uitoefenen. Een ideale solenoïde heeft binnenin een constant veld dat overal langs de as is gericht, buiten de solenoïde is het veld nul. Daarnaast nemen we aan dat het magnetisch materiaal homogeen en lineair is en een relatieve permeabiliteit $\mu_r$ heeft.
#
# <center>
# <img src="figures\solenoidactuatorgraph.png" width="1000">
# </center>
#
# **Opdracht 1**
#
# a. Pas de wet van Ampère toe voor het $\mathbf{H}$-veld met gebruik van contour $\cal C$.\
# b. Leidt een vergelijking af voor het $\mathbf{B}$-veld als functie van $z_p$.\
# c. Voldoet jouw afleiding aan de randvoorwaarden voor het H en B veld?

# %% [markdown]
# 1a:
# $\oint \vec{H} \cdot \vec{dl} = I_{enc}$
#
# Alle bijdrages van C vallen weg. Buiten de solenoide is B = 0, dus H ook. Verder vallen de linker en rechterkant van de lijnintegraal binnen de solenoide weg omdat die bijdrages elkaar opheffen. We krijgen dus
#
# $H L_s = I_{enc} = NI$
# $\vec{H} = \frac{IN}{L_s}\hat{z}$

# %% [markdown]
# 1b:
# $\vec{M} = (\mu _r - 1)\vec{H} = (\mu _r - 1)IN\hat{z}$
#
# B volgt uit
# $\vec{B} = \mu _0(\vec{H} + \vec{M})$
#
# Buiten het magnetiseerbaar materiaal is de magnetisatie gelijk aan 0, daarbinnen is die gelijk aan $\vec{M} = (\mu _r - 1)\vec{H}$
#
# Als functie van zp wordt het totale B-veld dan:
#
# $ \vec{B} = \begin{cases}
# \frac{\mu _0 IN}{L_s}\hat{z}  \ \ \ \ -\frac{1}{2}L_s \leq z \leq z_p \\
# \frac{\mu _0 \mu _r IN}{L_s} \hat{z} \ \ \ \ z_p \leq z \leq \frac{1}{2}L_s
# \end{cases}$

# %% [markdown]
# 1c: randvoorwaarden\
# Het H veld is gegeven door:
# $\vec H = \frac{IN}{L_s} \hat{z}$.\
# Het B veld in het algemeen (niet als functie van $z_p$) is gegeven door:\
# $\vec B = \frac{IN}{L_s} \mu _0 \mu _r \hat{z}$
#
# We weten dat beide velden geen loodrechte component hebben, aangezien ze beiden volledig parallel aan de solenoïde staan, dus deze randvoorwaarden geven we niet.\
#
# De randvoorwaarde voor de parallelle component van het H veld (volgens Griffiths vgl 6.25) is:\
# $\vec H^{||}_{above} - \vec H^{||}_{below} = \vec K_f \times \hat{n}$\
# $\vec H^{||}_{above}$ is 0, aangezien het H veld buiten de solenoïde 0 is.\
# Dus er geldt: $- \vec H^{||}_{below} = \vec K_f \times \hat{n}$\
# $\vec K_f \times \hat n = K_f (-\hat{z}) = -\frac{IN}{L_s} \hat{z}$\
# En zoals gezegd is $- \vec H^{||}_{below} = -\frac{IN}{L_s} \hat{z}$\
# Dus de afleiding voor het H veld voldoet aan de randvoorwaarde.\
#
# De randvoorwaarde voor de parallelle component van het B veld (volgens Griffiths vgl 6.27) is:\
# $\vec B^{||}_{above} - \vec B^{||}_{below} = \mu _0 (\vec K \times \hat{n})$\
# $\vec B^{||}_{above}$ is weer 0 aangezien het B veld buiten de solenoide 0 is.\
# $\vec K = \vec K_f + \vec K_b$, en om de gebonden ladingsdichtheid te vinden maken we gebruik van:\
# $\vec K_b = \vec M \times \hat{n}$\
# We weten: $\vec M = (\mu _r - 1) \vec H = (\mu _r - 1) \frac{IN}{L_s} \hat{z}$\
# $\vec K_b = \vec M \times \hat{n} = M (-\hat{y}) = (\mu _r - 1) \frac{IN}{L_s} \hat{y}$\
# We weten ook al van eerder: $\vec K_f = \frac{IN}{L_s}\hat{y}$
# Dit invullen in de randvoorwaarde geeft:\
# $- \vec B^{||}_{below} = \mu _0 (\vec K \times \hat{n}) $ = \
# $\mu _0 ((\mu _r - 1) \frac{IN}{L_s} + \frac{IN}{L_s})\hat{y} \times \hat{n}$ = \
# $- \mu_0 \mu _0\frac{IN}{L_s}\hat{z}$
#
# Dus de afleiding voor het B veld voldoet ook aan de randvoorwaarde.

# %% [markdown]
# Het randveld van de solenoïde zal de plunjer de solenoïde intrekken. Echter, het berekenen van de randvelden is een hele klus, we zullen dit later doen. We gebruiken hier een aanpak soortgelijk aan die voor een dielektricum in een condensator. Allereerst berekenen we de totale energie van het systeem met behulp van $W = \frac{1}{2} \int_{\cal V} \mathbf{H} \cdot \mathbf{B} \, d\tau $. Daarna bepalen we de kracht op de plunjer door de afgeleide van de energie naar de positie te nemen. We nemen aan dat de plunjer dezelfde straal heeft als de solenoide, $r_s$.
#
# **Opdracht 2**
#
# Bereken de totale hoeveelheid energie in de solenoïde als functie van $z_d$ door de veldenergie over het volume van de solenoïde te integreren met behulp van bovenstaande vergelijking.

# %% [markdown]
# $W = \frac{1}{2} \int_0^{2 \pi} \int_0^{r_s} \int_{-\frac{1}{2}L_s}^{z_p} r \frac{IN}{L_s}\hat{z} \cdot \frac{\mu _0 IN}{L_s}\hat{z} \ dz ds d \theta + \frac{1}{2} \int_0^{2 \pi} \int_0^{r_s} \int_{z_p}^{\frac{1}{2}L_s} r \frac{IN}{L_s}\hat{z} \cdot \frac{\mu _0 \mu _r IN}{L_s}\hat{z} \ dz ds d \theta $
#
# Uitgewerkt geeft
#
# $W = \frac{1}{2} \mu _0 \pi r_s^2 (\frac{IN}{L_s})^2 (z_p + \mu _r (L_s - z_p))$

# %% [markdown]
# Zoals je wellicht ziet uit je afleiding is de energie van de plunjer groter als de plunjer er geheel uit is en kleiner als de plunjer er geheel in is. De afgeleide van de energie naar de positie $z_p$ geeft dan ook een kracht die de plunjer naar buiten beweegt. Dit is fysisch niet wat er gebeurd. Wat we in de afleiding niet hebben meegenomen is de energie die het kost om de stroom te laten stromen. Het veranderende magneetveld veroorzaakt door het naar binnen bewegen van de magneet (wet van Faraday) geeft een stroom tegengesteld aan de aangelegde stroom, de stroombron moet dan dus meer vermogen gaan leveren om de stroom op gang te houden. Als we dit effect wel meenemen blijkt dat de grootte van de kracht gelijk is, maar dat deze dan de plunjer de solenoide intrekt. We gaan hier niet verder op in.
#
#
# **Opdracht 3**
#
# Bereken de kracht van de spoel op de plunjer.

# %% [markdown]
# afleiden naar $z_p$ geeft
#
# $F = \frac{1}{2} \mu _0 \pi r_s^2 (\frac{IN}{L_s})^2 (\mu _r -1) \hat{z}$

# %% [markdown]
# ## Deel 2: Criteria opstellen
#
# Jullie gaan nu een magnetische kracht actuator ontwerpen hiervoor gaan jullie nu een ontwerpcyclus doorlopen.
#
# **Opdracht 4**
#
# a. Bedenk en schets vijf toepassingen van een kracht actuator.\
#
# 1. Raam opener voor ramen die hoog zitten
# 2. Regulatie van water in verschillende cycli van een wasmachine
# 3. Elektronisch slot
# 4. Aansturing van gewrichten in proteses
# 5. Aansluiting en loslating van karretjes in een achtbaan
#
# b. Kies uit deze toepassingen minimaal 2 toepassingen voor een kracht actuator om verder mee door te rekenen.
#
# We gaan verderrekenen met toepassingen 1 en 2

# %% [markdown]
# <img src="figures\actuatorschetsen1.jpeg" width="400">
# <img src="figures\actuatorschetsen2.jpeg" width="400">

# %% [markdown]
# Uitleg toepassingen
# 1. Een lineaire actuator om een raam open en dicht te doen en stabiel open te houden. Deze kan op lange afstand worden bestuurd, wat handig is voor ramen die hoog zitten, zoals dakramen.
# 2. Een lineaire actuator die de instroom van water in een wasmachine kan regulieren. Actuators worden veel gebruikt in het regulieren van stromen en zijn handig omdat ze snel werken. De actuator zorgt van de op en neer beweging van de klep die de stroom tegenhoudt. Een wasmachine kan zo snel en geautomatiseerd wisselen tussen verschillende standen van water instroom in verschillende cycli.
# 3. Een elektronisch slot dat werkt met een lineaire actuator. De plunjer schuift in de solenoide en blijft daar vastzitten door het veld waardoor het stevig en veilig op slot zit. Dit kan bijvoorbeeld voor auto deuren worden gebruikt die automatisch op slot moeten kunnen.
# 4. Aansturing van gewrichten in protheses of robotische armen, hiervoor is een roterende beweging nodig. Dit kan worden aangestuurd door met een lineaire actuator kracht te zetten op de tandwielen (of eventueel een ander systeem waarmee de rotatie plaatsvindt), en door meerdere van dit soort mechanismes in de arm te zetten kun je veel individuele gewricht beweging creëeren.
# 5. Lineaire actuator om achtbaan karretjes aan elkaar vast te maken, zo kun je snel en veilig de karretjes los en vast maken vòòr de rit. De werking hiervan lijkt erg op de werking van het slot.

# %% [markdown]
# **Opdracht 5**
#
# We gaan nu verder kijken naar de criteria van jullie kracht actuatoren. Wij hebben alvast twee essentiele criteria vastgesteld zodat we hier later in de opdracht mee verder kunnen rekenen. Hieronder zijn 4 veelgebruikte stroombronnen benoemd die jullie gaan gebruiken voor een van de criteria.
#
# | Spanningsbron             | Stroomsterkte | Voltage | draad dikte van de spoel |
# |:--------------------------|:--------------|:--------|:-------------------------|
# | Arduino uno digital pin   | 40 mA         | 5 V     | 0.05 mm                  |
# | 9 Volt batterij           | 500 mA        | 9 V     | 0.1  mm                  |
# | 40 Watt telefoon oplader | 2 A           | 20 V    | 0.2 mm                   |
# | Een auto batterij         | 180 A         | 12 V    | 1.5 mm                   |
#
#
# a. Kies een van de hierboven benoemde stroombronnen om te gebruiken in jullie ontwerp. \
#
# Voor de raamopener nemen we de 9 volt batterij
# Voor de wasmachine nemen we de auto-batterij
#
# b. Gebruik de methode uit het college 'schattend rekenen' om voor elke toepassing de minimale kracht die de actuator moet kunnen leveren voor jullie toepassing te bepalen.\
# c. Denk na over wat de straal van jullie actuator mag zijn. \
# d. Bedenk nog 1 ander criterium per toepassing.

# %% [markdown]
# Plaats hier een foto van jullie uitwerkingen op vraag 5.

# %% [markdown]
# 5b:
# voor toepassing 1, de raamopener, kunnen we de kracht schatten door te beseffen die de actuator levert een raam moet optillen, en dus de zwaartekracht daarop moet tegenwerken.
# Een raam kan verschillende gewichten hebben. Ondergrens schatten op $\approx 1 kg$ en bovengrens op $\approx 200 kg$ geeft de geschatte massa van een raam $\sqrt{1*200} = 1.5 * 10 kg$
#
# Dan is de minimale kracht die de actuator moet leveren $m * g \approx 10 * 1.5 *10^1 \approx 1.5 * 10^2 N$
#
# Voor toepassing 2 is het lastiger om de kracht te schatten, aangezien we niet overduidelijk in een wasmachine weten wat de tegenwerkende kracht is die opgeheven moet worden. Wel weten we $P = UI$ en $P = Fv$. We kunnen zo de kracht schatten door te schatten hoe snel de wasmachine van de ene stand naar de ander moet kunnen switchen. $P = UI = 180 * 12 \approx 200 * 10 \approx 2000 W$
#
# Ondegrens voor v $\approx 10^{-1} mm/s$, bovengrens $\approx 100 mm/s$, dus $v \approx \sqrt{100*10^{-1}} \approx 10 mm/s \approx 10^{-2} m/s$
#
# Dan $F = \frac{P}{v} \approx \frac{2000}{1.5 * 10^{-2}} \approx 10^5 N$

# %% [markdown]
# 5c:
# Afhankelijk van het materiaal kan de draagkracht van de actuator verschillen, bij de meest gebruikte materialen schatten wij dat de oppervlakte minstens 0.6 mm^2 moet zijn, deze straal kan wel maar het lijkt ons beter als de straal groter is, rond de 3 cm voor de raamactuator en 2 cm voor de wasmachine.

# %% [markdown]
# 5d:
# Voor de raamopener moet de lengte van 30 cm kunnen bereiken, maximum lengte 40 cm. Minimum lengte moet 0 zijn, want het raam moet goed dicht kunnen.
#
# De wasmachine moet in zijn grootste stand ongeveer 1 cm open staan, met daartussen 4 standen waarin water op verschillende snelheden naar buiten stroomt. De lengte moet dus stabiel blijven op verschillende spanningen.

# %% [markdown]
# ## Deel 3: Simuleren om de grenzen van jullie ontwerpparameters te bepalen
#
# Jullie zullen nu simulaties gaan uitvoeren om de grenzen van jullie ontwerpparameters op te zoeken. Dit doen jullie voor jullie twee gekozen toepassingen en een deuractuator. Deze deuractuator moet een deur van het slot afhaalen door een kracht van 40 N uit te oefenen, gebruikt een 9 volt batterij als stroombron, de plunjer is gemaakt van ijzer en de straal van de actuator is 0.01 m.
#
# **Opdracht 6**
#
# Zet de relevante parameters in een Python script en maak een Python functie die met behulp van de wet van Ohm de maximale draadlengte uitrekent. Print de maximale draadlengte bij het uitvoeren van het script.

# %% [markdown]
# ## Afleiding
# We doen de afleiding met behulp van de formule
#
# $R = \frac{\rho L}{A}$
#
# waarbij $\rho$ de soortelijke weerstand van de stroomdraad is, L de lengte van de stroomdraad, en A de oppervlakte van de dwarsdoorsnede
#
# verder weten we uit de wet van ohm
#
# $R = \frac{U}{I}$
#
# Dit combineren geeft een uitdrukking voor de draadlengte:
#
# $L = \frac{AU}{\rho I}$

# %%
def L_draad_max(d, rho, V, I):
    A = (np.pi * (d)**2) #We gaan ervanuit dat de dikte gegeven in de tabel een straal is
    return ((A*V)/(rho * I))

# Stroomdraden zijn vaak gemaakt van koper, dus we gebruiken de soortelijke weerstand van koper
rho_koper = 0.0175e-6 # in ohm m bij 20*C (bron wikipedia)

L_deur = L_draad_max(0.1e-3, rho_koper, 9, 500e-3) #Waardes uit bovenstaande tabel
L_wasmachine = L_draad_max(1.3e-3, rho_koper, 12, 180) # We zouden een auto-batterij gebruiken voor de wasmachine
L_raam = L_draad_max(0.1e-3, rho_koper, 9, 500e-3) #Zelfde stroombron gekozen als voor de deur, dus zelfde L_max

print(f"De maximale draadlengte voor de deuractuator is {L_deur:.4g} m")
print(f"De maximale draadlengte voor de raamopener is {L_raam:.4g} m")
print(f"De maximale draadlengte voor de wasmachine actuator is {L_wasmachine:.4g} m")
# Out:
# De maximale draadlengte voor de deuractuator is 32.31 m
# De maximale draadlengte voor de raamopener is 32.31 m
# De maximale draadlengte voor de wasmachine actuator is 20.23 m

# %% [markdown]
# **Opdracht 7**
#
# Leidt een vergelijking af voor het minimale aantal wikkelingen $N$ die je nodig hebt om het gewicht op te kunnen tillen. Voeg je afleiding als png toe aan je notebook.

# %% [markdown]
# Het omschrijven van de krachtformule afgeleid bij deel 1 geeft:
#
# $N = \frac{L_s}{r_s I} \sqrt{\frac{2F}{\pi \mu _0 (\mu _r -1)}}$

# %% [markdown]
# We gaan nu de ontwerpvrijheid verkennen. Gegeven de materiaalparameters en de eigenschappen van de stroombron kunnen we de verhouding tussen de lengte en de straal van de solenoide kiezen.
#
# **Opdracht 8**
#
# Schrijf een enkele Python functie die het minimum en maximum aantal wikkelingen uitrekent als functie van $L_s$, $r_s$, $r_d$ en $I$. De functie moet de volgende voorwaarden controleren
# 1) Het minimum aantal wikkelingen wordt gegeven door de hiervoor afgeleide relatie van het aantal wikkelingen om de benodigde kracht te genereren.
# 2) Het maximum aantal wikkelingen wordt gegeven door de draaddikte $r_d$ en de lengte $L_s$
# 3) Het maximum aantal wikkelingen wordt gegeven door de draadlengte en de straal van de solenoide
# 4) Het maximum aantal wikkelingen moet groter zijn dan het minimum aantal wikkelingen
#
# Het maximum aantal wikkelingen is de kleinste van voorwaarde 2) en 3). Geef een foutmelding als het minimum aantal windingen groter is dan het maximum aantal windingen.

# %% [markdown]
# Voor N1 max (aanname dat de wikkelingen heel dicht op elkaar liggen):
# :
# <img src="afleidingN1.jpeg" width="1000">

# %% [markdown]
# Voor N2 max:
# <img src="afleidingN2.jpeg" width="1000">

# %%
### BEGIN SOLUTION

def aantal_wikkelingen(Ls, rs, rd, I, Ldraad, F):
    mu0 = 4*np.pi *1e-7 #N/A^2
    mur = 50000 #geschat, relatieve permeabiliteit van ijzer op basis van internet
    N_min = (Ls/(rs*I)) * np.sqrt(((2*F)/(mu0*np.pi*(mur-1)))) # op basis van afleiding hierboven
    N_max_1 = Ls/(2*rd) #Dikte van de draad is een straal niet een diameter in deze berekening
    N_max_2 = Ldraad/(2*np.pi*rs)
 
    # print("N_max_1 =", N_max_1)
    # print("N_max_2 = ", N_max_2)

    N_max = np.minimum(N_max_1,N_max_2)

    # print("Nmin =", N_min)

    if np.any(N_min > N_max): ## Als het ontwerp niet mogelijk is.
        print("The design with L_s =", Ls[N_min > N_max], "has no workable solution")
        N_min[N_min > N_max] = 'NaN'
        N_max[N_min > N_max] = 'NaN'

    return N_min, N_max

# %% [markdown]
# Een parameter plot geeft ons inzicht in de haalbaarheid van het idee. In dit geval willen we kijken naar het mogelijke aantal wikkelingen en de lengte van onze solenoide. Hieronder staat een voorbeeld van code die een voorbeeld plot creëert met minimale eis $y=x$ en de maximale eis $y=2x$.

# %%
x = np.linspace(0,10,100)
y_min = x # Minimale eis
y_max = 2*x # Maximale eis

plt.fill_between(x,y_min,y_max) # De ruimte tussen de eisen vullen
plt.title("Voorbeeld parameter plot")
plt.xlabel("x")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# **Opdracht 9**
#
# Maak een parameterplot met behulp van bovenstaand gedefinieerde functie voor de drie solenoideactuatoren voor $L_s$ tussen 0 en 1 m in 50 stappen. Een parameter plot ziet er hier uit als een plot tussen het minimale aantal wikkelingen en het maximaal aantal wikkelingen.

# %%
Ls = np.linspace(0, 1, 50) #Als we Ls

# Volgorde van variabeles ingevoerd: (Ls, rs, rd, I, Ldraad, F), allemaal in standaard SI eenheden
# F voor de raam en wasmachine komen voort uit de schattingen in deel 2, zelfde voor rs

N_min_deur, N_max_deur = aantal_wikkelingen(Ls, 0.01, 0.1e-3, 500e-3, L_deur, 40)
N_min_raam, N_max_raam = aantal_wikkelingen(Ls, 0.03, 0.1e-3, 500e-3, L_raam, 1.5e2)
N_min_wasmachine, N_max_wasmachine = aantal_wikkelingen(Ls, 0.02, 1.5e-3, 180, L_wasmachine, 1e5)

plt.figure()
plt.fill_between(Ls,N_min_deur,N_max_deur) # De ruimte tussen de eisen vullen
plt.title("Deuractuator")
plt.xlabel("Ls [m]")
plt.ylabel("N [-]")
plt.show()

plt.figure()
plt.fill_between(Ls,N_min_raam,N_max_raam) # De ruimte tussen de eisen vullen
plt.title("Raamactuator")
plt.xlabel("Ls [m]")
plt.ylabel("N [-]")
plt.show()

plt.figure()
plt.fill_between(Ls,N_min_wasmachine,N_max_wasmachine) # De ruimte tussen de eisen vullen
plt.title("Wasmachine actuator")
plt.xlabel("Ls [m]")
plt.ylabel("N [-]")
plt.show()
# Out:
# The design with L_s = [0.14285714 0.16326531 0.18367347 0.20408163 0.2244898  0.24489796
#  0.26530612 0.28571429 0.30612245 0.32653061 0.34693878 0.36734694
#  0.3877551  0.40816327 0.42857143 0.44897959 0.46938776 0.48979592
#  0.51020408 0.53061224 0.55102041 0.57142857 0.59183673 0.6122449
#  0.63265306 0.65306122 0.67346939 0.69387755 0.71428571 0.73469388
#  0.75510204 0.7755102  0.79591837 0.81632653 0.83673469 0.85714286
#  0.87755102 0.89795918 0.91836735 0.93877551 0.95918367 0.97959184
#  1.        ] has no workable solution
# The design with L_s = [0.08163265 0.10204082 0.12244898 0.14285714 0.16326531 0.18367347
#  0.20408163 0.2244898  0.24489796 0.26530612 0.28571429 0.30612245
#  0.32653061 0.34693878 0.36734694 0.3877551  0.40816327 0.42857143
#  0.44897959 0.46938776 0.48979592 0.51020408 0.53061224 0.55102041
#  0.57142857 0.59183673 0.6122449  0.63265306 0.65306122 0.67346939
#  0.69387755 0.71428571 0.73469388 0.75510204 0.7755102  0.79591837
#  0.81632653 0.83673469 0.85714286 0.87755102 0.89795918 0.91836735
#  0.93877551 0.95918367 0.97959184 1.        ] has no workable solution
# The design with L_s = [0.59183673 0.6122449  0.63265306 0.65306122 0.67346939 0.69387755
#  0.71428571 0.73469388 0.75510204 0.7755102  0.79591837 0.81632653
#  0.83673469 0.85714286 0.87755102 0.89795918 0.91836735 0.93877551
#  0.95918367 0.97959184 1.        ] has no workable solution

# %% [markdown]
# **Opdracht 10**
#
# Maak voor elke actuator een keuze voor de lengte van de spoel, de straal van de spoel en de lengte van de draad.

# %% [markdown]
# We zien in de bovenstaande grafieken dat ze breder worden naarmate N en Ls groter worden. Het kiezen van een grotere N in ons ontwerp zou dus in theorie beter bestand zijn tegen mogelijke onvoorziene fluctuaties.
#
# De lengte van de draad en de straal van de spoel hadden we ingevoerd in de functies om deze grafieken te krijgen. Het is dan ook logisch om deze waardes hetzelfde te houden.
#
# Conclusie:
#
# Voor de deur, keuze voor: \
# N = 500 \
# Ls = 0.11 m \
# Ldraad = 32.31 m \
# rs = 0.01
#
# Voor de raamactuator, keuze voor: \
# N = 150 \
# Ls = 0.04 m \
# Ldraad = 32.31 m \
# rs = 0.03
#
# Voor de wasmachine actuator, keuze voor: \
# N = 200 \
# Ls = 0.65 m \
# Ldraad = 26.93 m \
# rs = 0.02 m

# %% [markdown]
# Bovenstaande analytische berekening is een goede start voor het ontwerp en geeft aan welke parameters je kan optimaliseren. Echter in een echte solenoide zullen er allerlei niet ideale effecten een rol spelen. Zo zal het veld in de solenoide niet constant zijn (het is geen oneindig lange solenoide) en zijn er randvelden aan de uiteinden van de solenoide. We zullen nu de kracht-afstand relatie van de solenoide krachtactuator uitrekenen. Deze kan dan verder geoptimaliseerd worden om de kracht-uitwijking relatie zo lineair mogelijk te maken.

# %% [markdown]
# ## Deel 4: Numeriek berekenen van het magneetveld van een rechte stroomdraad
#
# <img align="right" style="margin-left:15px" src="wiregeometry.jpg" width="300">
#
# Omdat we in ons ontwerp een stroombron gebruiken met een aangelegde stroom voeren we de berekeningen uit met het $\mathbf{H}$-veld. De analytische oplossing voor het $\mathbf{H}$-veld om een oneindig lange stroomdraad is het met meest eenvoudige voorbeeld voor het berekenen van het magnetisch veld en het toepassen van de wet van Ampere. In cilindrische coordinaten wordt het magneetveld op afstand $s$ veroorzaakt door stroom $I$ gegeven door (zie Griffiths blz. 282, voorbeeld 6.2)
# $$
#     \mathbf{B} =\frac{I}{2 \pi s} \hat{\boldsymbol{\phi}} \, .
# $$
#
#
# Alleen in de meest eenvoudige stroomgeometrieën kunnen we het magneetveld analytisch berekenen. In meer complexe stroomgeometrieën moeten we numerieke methoden gebruiken om het magneetveld te berekenen. In deze opdracht willen we een numerieke methode ontwikkelen voor een complexe stroomgeometrie, maar gebruiken we het voorbeeld van de oneindig lange stroomdraad om onze numerieke methode te testen. We gaan het magneetveld berekenen met de wet van Biot-Savart (zie Griffiths blz. 222, Vgl. 5.34) maar dan voor het $\mathbf{H}$-veld
#
# $$
#     \mathbf{H}(\mathbf{r}) = \frac{1}{4 \pi} I \int \frac{d \mathbf{l}' \times \widehat{(\mathbf{r} - \mathbf{r}')}}{|\mathbf{r} - \mathbf{r}'|^2} \, .
# $$
#
# De wet van Biot-Savart laat zien dat het magneetveld wordt gegeven door een som over lijnelementen $d\mathbf{l}$ met bijdrage
#
# $$
#     d\mathbf{H}(\mathbf{r}) = \frac{1}{4 \pi} I  \frac{d \mathbf{l}' \times \widehat{(\mathbf{r} - \mathbf{r}')}}{|\mathbf{r} - \mathbf{r}'|^2} \, .
# $$
#
# **Opdracht 11**
#
# Schrijf een Python funktie met als invoer de variabelen:
# * een array die de veldpositie $\mathbf{r}$ aangeeft
# * een array die de de bronpositie $\mathbf{r}'$ aangeeft
# * een array die de lengte $d\mathbf{l}$ aangeeft
#
# De functie moet het magneetveld van een lijnelement $d\mathbf{l}$ berekenen. Gebruik voor het uitrekenen van het uitproduct de numpy $\verb|cross|$ functie en de hierboven gegeven formule voor $d\mathbf{H}$.
#
# Bereken met deze functie alle componenten van het magneetveld voor een veldpositie op $x=0.1$ m voor een stroombronelement in de oorsprong met een stroom van 6 A een lengte van $d\mathbf{l}$ gelijk aan $L/64$. Print het analytische en numerieke antwoord naar de command line en controleer dat het magneetveld gelijk is aan $\mathbf{H} =  0.00746 \hat{\mathbf{y}}$ A/m is.

# %%
L_draad = 0.1
dl=np.array([0, 0, L_draad/64])
r_field=np.array([0.1, 0, 0])
r_source=np.array([0, 0, 0])
I = 6

# functie om dH te berekenen
def field_current_element(r_field, r_source, dl):
    r_vec = (r_field - r_source) 
    r_unitvec = r_vec / np.linalg.norm(r_vec)
    dH = ((I/4/np.pi) * (np.cross(dl, r_unitvec))) / (np.linalg.norm(r_vec)**2)
    # r_field are coordinates at which we want to calculate the field
    # r_source are coordinates of the current source
    # dl is the vector of the length of the current element
    # Gebruik np.cross om het uitproduct te berekenen
    return dH
analytical_answer=(I/4/np.pi)*(L_draad/64)/np.sum((r_field-r_source)**2) # een veld elementje.
print('The analytical answer is ' + str(analytical_answer) + ' A/m in the y-direction')

print('The numerical answer is ' + str(field_current_element(r_field, r_source, dl)[1]) + ' A/m in the y direction')
# Out:
# The analytical answer is 0.07460387957432593 A/m in the y-direction
# The numerical answer is 0.07460387957432593 A/m in the y direction

# %% [markdown]
# Nu gaan we met behulp van de numerieke implementatie van de wet van Biot-Savart het magneetveld uitrekenen in het vlak loodrecht op de draad. We nemen daarom een eindige lengte van de draad en verdelen dit in kleine stukken met lengte $d\mathbf{l}$. Daarna integreren we over de gehele lengte door de bijdrage van al deze stukken op te tellen en zo het magneetveld te bepalen. Voor het correct uitvoeren van deze numerieke integratie is het van belang dat we en een lang genoeg stuk draad nemen en dat we dit in genoeg kleine delen ophakken.
#
# **Opdracht 12**
# * Creëer een array met de veldcoordinaat $\mathbf{r}$.
# * Bereken een array met alle contributies $dH$ op $r=(x,y,z)=(0.1, 0, 0)$ m.
# * Plot de contributies tegen de locatie van de bijbehorende bron.
# * Bereken het $H$ veld door over alle contributies te someren.
# * Print een regel met het numerieke antwoord en vergelijk dit met het analytische antwoord.
# * Bestudeer hoe de bijdragen varieren voor de verschillende locaties en hoe groot L en het aantal stappen moet zijn om een numeriek correct resultaat te krijgen.
#
# Deze opdracht kan ook gemaakt worden met het gebruik van for loops, De akauze voor methode is aan jullie.

# %%
N = 10000 # aantal stappen

# maken van arrays
r_field = np.array([0.1, 0, 0])
dH_array = np.zeros(shape=(N, 3))
r_sourcearray = np.zeros(shape=(N,3))

# lengte van de draad, negatief zodat het gelijk de z as wordt
L_nieuw = np.linspace(-100, 100, N) # de lengte van de draad is dus 200 nu, groter maken geeft betere benadering
dl = np.array([0, 0, (L_nieuw[1]-L_nieuw[0])])

# for loop om op elk punt van de draad de contributie dH te berekenen
for i in range(N):
    r_source = np.array([0, 0, L_nieuw[i]])
    r_sourcearray[i] = r_source
    # print(r_source)
    dH_array[i] = field_current_element(r_field, r_source, dl)

plt.figure()
plt.plot(r_sourcearray, dH_array, 'k.', label = 'contributies op locaties bron')
plt.xlabel('Locatie bron (m)')
plt.ylabel('Veld contributie (A/m)')
plt.legend()


# H veld is de som van alle contributies, komt inderdaad overeen met het analytisch antwoord
# Hoe groter je N en L maakt, hoe meer decimalen overeenkomen van het numerieke antwoord en het analytische antwoord
H_veld = np.sum(dH_array)
print('The numerical answer is ' + str(H_veld) + ' A/m in the y-direction')
print('The analytical answer is ' + str(I / (2 * np.pi * 0.1)) + ' A/m in the y-direction')
# grafiek is een beetje raar maar vorm is wel logisch
# Out:
# The numerical answer is 9.549291811822249 A/m in the y-direction
# The analytical answer is 9.549296585513721 A/m in the y-direction

# %% [markdown]
# ### Deel 5: Numeriek berekenen van het magneetveld van een solenoide
#
# We gaan nu het magneetveld van onze solenoide uitrekenen. Deze solenoide is een draad die om een cylinder gewikkeld is. Hieronder is een functie gegeven die de draad van een solenoide parametriseert. Deze parametrisatie gaan jullie gebruiken in combinatie met Biot-Savart om het H veld rond de solenoide te berekenen.

# %%
def parametrisatie(N,r_sol,aantal_omwentelingen,L_sol):
    t=np.linspace(0, 1, N)
    x = r_sol * np.cos(2 * np.pi * aantal_omwentelingen*t) # x coordinaten
    y = r_sol * np.sin(2 * np.pi * aantal_omwentelingen*t) # y coordinaten
    z = L_sol* t - L_sol/2  # z componenten
    return x,y,z

# %% [markdown]
# **Opdracht 13**
#
# Bereken het traject van een stroomdraad met een straal van $r_{sol}$. De solenoide met lengte $L_{sol}$ is gecentreerd op de oorsprong met de cilinderas langs de $z$-as. Doe dit door de hierboven gegeven functie te gebruiken.
#
# a. Bereken het aantal omwentelingen van je draad, hierbij mag je aannemen dat de omtrek een cirkel is (in feite is het een ellips, maar omdat de windingen zo dicht op elkaar zitten is het vrijwel een cirkel).\
# b. Bereken de $x$, $y$ en $z$ coordinaten.\
# c. Bereken de spoed, in eenheden van aantal omwentelingen per meter, en print dit.

# %%
# Dit zijn voor nu even placeholders, ik weet niet welke waardes ze hier willen, dus ik heb geschat op basis van de gegeven waardes van de deuractuator
# dit zijn nu de waardes van de deuractuator
L_sol = 0.11
l_draad = 32.31
r_sol = 0.01

#aantal omwentelingen op basis van de aanname dat het een cirkel is

N = l_draad / (2*np.pi*r_sol)

#N in de formule is het aantal punten, niet het aantal wentelingen
aantal_punten = 5000

x, y, z = parametrisatie(aantal_punten, r_sol, N, L_sol)
# Enkele plots
ax=plt.figure().add_subplot(projection='3d')
plt.title('Traject van de draad van de solenoide')
plt.plot(x, y, z, '-r', linewidth=0.1)
ax.set_box_aspect(aspect=None, zoom=0.8)
ax.set_xlabel('x (m)'), ax.set_ylabel('y (m)'), ax.set_zlabel('z (m)')

spoed = N/L_sol

print(f"de spoed is {spoed:.4g} wentelingen per meter")
# Out:
# de spoed is 4675 wentelingen per meter

# %% [markdown]
# Het veld in een oneindig lange solenoide wordt gegeven door $\mathbf{H} = n I \hat{\mathbf{z}}$, met $n$ de spoed van de draad, en $I$ de stroom.
#
# **Opdracht 14**
#
# Bereken het veld in het midden van de solenoide en vergelijk het met het analytische antwoord voor een oneindig lange solenoide. Verhoog $N$ net zo lang tot jullie antwoord convergeert naar het analytisch antwoord.
# * Denk na over wat dl betekent en hoe jullie deze zou berekenen.
# * Bereken met de functie die jullie eerder geschreven hebben de contributies aan het $H$-veld en sommeer deze.

# %%
#weer een placeholder voor als we de echte waardes doen
I_oneindig = 500e-3 #A

H_oneindig = spoed * I_oneindig
print(f"Berekende veld is H = {H_oneindig:.4g} A/m")
# Out:
# Berekende veld is H = 2337 A/m

# %%
# Locatie van sources is nu x y z array
# We kijken op de oorsprong
# dl is de afgeleide van de x y z array
# Dan moet je die functie gebruiken enzo

# dl is de afgeleide van de positie array, die berekenen we met deze loop
dl_deel5 = np.zeros((len(x) - 1, 3))

for i in range(len(x) - 1):
    dl_x = x[i+1] - x[i]
    dl_y = y[i+1] - y[i]
    dl_z = z[i+1] - z[i]

    dl_deel5[i] = [dl_x, dl_y, dl_z]

# %%
# Ik kopieer de functie hier nogmaals want andere branch heeft m, dit kunnen we later weghalen als we alles samenvoegen

I = 500e-3 #A

# def field_current_element(r_field, r_source, dl):
#     print(dl.shape)
#     print((r_field - r_source).shape)
#     dH = (I / (4*np.pi)) * (np.cross(dl, (r_field - r_source))) / (np.linalg.norm(r_field - r_source)**3)
#     # r_field are coordinates at which we want to calculate the field
#     # r_source are coordinates of the current source
#     # dl is the vector of the length of the current element
#     # Gebruik np.cross om het uitproduct te berekenen
#     return dH

# Ik heb de functie hier licht aangepast, nu werkt de opdracht wel

def field_current_element(r_field, r_source, dl, I):
    r = r_field - r_source
    r_norm = np.linalg.norm(r, axis=1)  # axis = 1 zorgt ervoor dat per rij de norm genomen word
    dH = (I / (4*np.pi)) * np.cross(dl, r) / (r_norm[:, None]**3) #[:, None] is nodig zodat we delen door een kolomvector. Anders geeft python een error
    return dH

# r_source zijn hier de x, y, z waardes, want de solenoide is de ladingsbron. We laten de laatste waarde weg zodat de shapes van de arrays nog passen

r_source_deel5 = np.zeros((len(x) - 1, 3))

for i in range(len(x) -1):
    r_source_deel5[i] = [x[i], y[i], z[i]]

# r_field is de oorsprong want we bepalen het Hveld op dat punt

r_field_deel5 = np.array([0,0,0])

dH_deel5 = field_current_element(r_field_deel5, r_source_deel5, dl_deel5, I)
H_num = np.sum(dH_deel5, axis=0)  # we sommeren de componenten van H, axis = 0 zorgt ervoor dat we de kolommen sommeren

# We printen alleen de z-component, want vanwege de symmetrie vallen de x en y component weg. De z-component zal moeten convergeren, en dat doet hij ook
print("H_num =", H_num[2], "A/m")
print("H_analytic =", H_oneindig, "A/m")
# Out:
# H_num = 2142.9023161991663 A/m
# H_analytic = 2337.4073687723358 A/m

# %% [markdown]
# ### Deel 6: Bereken krachtrespons van een kracht actuator
# Omdat onze solenoide niet oneindig lang is zal het veld in de solenoide niet uniform zijn en ook niet op alle plaatsen exact langs de as gericht zijn.
#
# **Opdracht 15**
#
# Bereken de $z$-component van het $\mathbf{H}$-veld op de as van de solenoide over het interval $z \in [0, 1.5L_s]$ in 25 stappen. Je moet nu dus op elk veld-punt met behulp Biot-Savart de bijdragen van alle stroomelementen integreren. Maak een grafiek van de $z$-component van het $\mathbf{H}$-veld tegen $z$.

# %%
n_ax=25
z_ax=np.linspace(0, 1.5*L_sol/2, n_ax)
H_ax=np.zeros((n_ax,1))

aantal_omwent = N


def field_current_element(r_field, r_source, dl):
    r_vec = (r_field - r_source) 
    r_unitvec = r_vec / np.linalg.norm(r_vec)
    dH = ((I/4/np.pi) * (np.cross(dl, r_unitvec))) / (np.linalg.norm(r_vec)**2)
    # r_field are coordinates at which we want to calculate the field
    # r_source are coordinates of the current source
    # dl is the vector of the length of the current element
    # Gebruik np.cross om het uitproduct te berekenen
    return dH

for i_field in range(n_ax):
    print(f"\rIfield =  {i_field}", end="")# Print welk element van het veld nu berekend wordt.
    # Bepaal de field coordinate
    r_field = np.array([0, 0, z_ax[i_field]])
    Hsimulated=np.array([0,0,0],dtype='float64')
    n_sources = len(r_source_deel5)
    for i_source in np.arange(n_sources):
        r_source = r_source_deel5[i_source] # zo bepaal je voor elke r_field alle bijdragen
        # print(r_source)
        # print(r_field)
        # Bepaal dl en r_source en gebruik
        # print(r_source)
        # print(r_field)
        # print(field_current_element(r_field, r_source, dl))
        # print(dl_deel5)
        Hsimulated += field_current_element(r_field, r_source, dl_deel5[i_source])
        #print(f"Isource =  {i_source}", end="")
        print(Hsimulated)

    # selecting the z-component
    H_ax[i_field,0]=Hsimulated[2]
    
H_veld_ideaal=analytical_answer*np.ones(n_ax)*(1.0*(z_ax < L_sol/2))

# dit is nog een aardige analytische uitdrukking die je kan uitrekenen voor de z-component op de as van een solenoide met eindige lengte
H_veld_analytisch=(aantal_omwent*I/L_sol/2)*((L_sol/2-z_ax)/np.sqrt((z_ax- L_sol/2)**2 + r_sol**2)+(L_sol/2+z_ax)/np.sqrt((z_ax+ L_sol/2)**2 + r_sol**2))

plt.figure(figsize=[13,4])
plt.subplot(131)
plt.title('z-component van B-veld')
plt.plot(z_ax, H_veld_ideaal, '-r', label='ideaal')
plt.plot(z_ax, H_veld_analytisch, '-g', label='analytisch')
plt.plot(z_ax, H_ax, '-k', label='simulatie')
plt.xlabel('Afstand langs de as van de solenoide (m)')
plt.ylabel('H-veld (A/m)')
plt.legend()
# Out:
# Ifield =  0[0.07544525 0.02521689 0.01371732]
# [0.1205204  0.09083516 0.02745059]
# [0.11698194 0.17042582 0.04119983]
# [0.06618422 0.2318788  0.05496507]
# [-0.01143745  0.25035738  0.06874633]
# [-0.08458753  0.21833598  0.08254364]
# [-0.12372789  0.14866479  0.09635703]
# [-0.1130053   0.06941312  0.11018651]
# [-0.05667233  0.01256089  0.12403211]
# [0.02259863 0.00109408 0.13789386]
# [0.09284032 0.03971136 0.15177179]
# [0.12568172 0.11289922 0.16566591]
# [0.10780722 0.19116399 0.17957625]
# [0.04635528 0.24291725 0.19350283]
# [-0.03393215  0.24722514  0.2074457 ]
# [-0.10067116  0.20227581  0.22140485]
# [-0.12689783  0.12614024  0.23538033]
# [-0.10196207  0.04950725  0.24937216]
# [-0.03585221  0.00331353  0.26338036]
# [0.04480573 0.00625466 0.27740496]
# [0.1074717  0.05721869 0.29144598]
# [0.1268192  0.13570469 0.30550345]
# [0.0949709  0.21006934 0.3195774 ]
# [0.02470561 0.25028457 0.33366785]
# [-0.05566891  0.24006256  0.34777482]
# [-0.11372019  0.1834525   0.36189834]
# [-0.12597797  0.10323708  0.37603844]
# [-0.08742319  0.0317638   0.39019515]
# [-0.01354259 -0.00209937  0.40436848]
# [0.06589183 0.01537642 0.41855846]
# [0.11882009 0.07721511 0.43276513]
# [0.12383362 0.1585201  0.4469885 ]
# [0.07883453 0.22649768 0.46122861]
# [0.00191232 0.25368398 0.47548547]
# [-0.07592789  0.22904065  0.48975912]
# [-0.12326255  0.16243649  0.50404958]
# [-0.12093499  0.08069557  0.51835687]
# [-0.06980817  0.01679429  0.53268103]
# [ 0.0095528  -0.0034421   0.54702207]
# [0.08515261 0.02822358 0.56138004]
# [0.12646487 0.09908775 0.57575494]
# [0.11675831 0.18060234 0.59014681]
# [0.05987262 0.23987537 0.60455568]
# [-0.02129977  0.25294318  0.61898157]
# [-0.09402616  0.21445856  0.6334245 ]
# [-0.12893291  0.13987838  0.64788451]
# [-0.11186911  0.05925568  0.66236162]
# [-0.04964307  0.00512951  0.67685586]
# [ 3.26937885e-02 -6.07619804e-04  6.91367259e-01]
# [0.1019322  0.04443553 0.70589583]
# [0.13009939 0.12215325 0.72044162]
# [0.10576011 0.20122059 0.73500464]
# [0.03865892 0.24971911 0.74958492]
# [-0.04418097  0.2480218   0.76418249]
# [-0.10934043  0.19673587  0.77879738]
# [-0.13048619  0.11648907  0.79342962]
# [-0.09901297  0.03963308  0.80807922]
# [-0.02754506 -0.00279897  0.82274622]
# [0.05512717 0.0063769  0.83743065]
# [0.11564523 0.06353663 0.85213253]
# [0.12954259 0.14567876 0.86685189]
# [0.09113605 0.21968026 0.88158876]
# [0.01584936 0.25565294 0.89634316]
# [-0.06598066  0.23901482  0.91111513]
# [-0.12132823  0.17640088  0.92590469]
# [-0.12780737  0.09301754  0.94071187]
# [-0.08272608  0.0224955   0.95553669]
# [-0.00420383 -0.00667435  0.97037919]
# [0.07611099 0.01734891 0.98523938]
# [0.12579686 0.08494985 1.00011731]
# [0.12474693 0.16890506 1.015013  ]
# [0.07330574 0.23534608 1.02992647]
# [-0.00783795  0.25742223  1.04485775]
# [-0.08597163  0.22615159  1.05980688]
# [-0.12954678  0.15407508  1.07477388]
# [-0.12091728  0.07022723  1.08975877]
# [-0.06348519  0.00844033  1.1047616 ]
# [ 0.0196397  -0.00630666  1.11978237]
# [0.0949388  0.03201363 1.13482114]
# [0.13200035 0.10801389 1.14987791]
# [0.11580197 0.19107069 1.16495272]
# [0.05279963 0.24766369 1.1800456 ]
# [-0.03164508  0.25490377  1.19515658]
# [-0.10347407  0.20979046  1.21028569]
# [-0.13366893  0.1304545   1.22543295]
# [-0.10997401  0.04887139  1.24059839]
# [-0.04187061 -0.0020259   1.25578205]
# [ 0.04321659 -0.00164096  1.27098395]
# [0.11096314 0.04995151 1.28620412]
# [0.13399125 0.13200335 1.30144259]
# [0.10293362 0.21143673 1.31669939]
# [0.03024357 0.25617885 1.33197454]
# [-0.05479825  0.24811184  1.34726809]
# [-0.11787838  0.19040921  1.36258005]
# [-0.13349558  0.10628828  1.37791045]
# [-0.09527     0.02966854  1.39325933]
# [-0.01854902 -0.00850537  1.40862671]
# [0.06575445 0.00723878 1.42401263]
# [0.12361751 0.07062996 1.43941711]
# [0.13163795 0.15615126 1.45484019]
# [0.08649898 0.22931107 1.47028189]
# [0.00633999 0.26055385 1.48574224]
# [-0.0765327   0.23719996  1.50122127]
# [-0.12866607  0.16859141  1.51671901]
# [-0.1289642   0.08235515  1.5322355 ]
# [-0.07722463  0.01327855  1.54777076]
# [ 0.00574681 -0.01072364  1.56332482]
# [0.08650241 0.0201102  1.57889771]
# [0.13243601 0.09341878 1.59448946]
# [0.12494805 0.17967333 1.61010011]
# [0.0669768  0.24407168 1.62572968]
# [-0.01815369  0.26058023  1.6413782 ]
# [-0.09611765  0.22245808  1.65704571]
# [-0.13542804  0.14500914  1.67273223]
# [-0.120153    0.05943865  1.68843779]
# [-5.63726153e-02  2.80286515e-04  1.70416243e+00]
# [ 0.03024079 -0.00854048  1.71990618]
# [0.10475588 0.03661757 1.73566906]
# [0.13707009 0.11760909 1.7514511 ]
# [0.11407029 0.20179313 1.76725235]
# [0.04495389 0.25518787 1.78307282]
# [-0.04244882  0.25618766  1.79891256]
# [-0.11288061  0.20430534  1.81477158]
# [-0.13787958  0.1204026   1.83064992]
# [-0.10728063  0.03830175  1.84654762]
# [-0.0333485  -0.00884843  1.8624647 ]
# [ 0.05413795 -0.00195657  1.8784012 ]
# [0.11988013 0.05628124 1.89435714]
# [0.13730173 0.14243512 1.91033256]
# [0.09929202 0.22176742 1.92632749]
# [0.02110776 0.262239   1.94234196]
# [-0.06575054  0.24744841  1.95837601]
# [-0.12623007  0.18327852  1.97442965]
# [-0.13587165  0.09555717  1.99050294]
# [-0.09070134  0.01966177  2.00659588]
# [-0.00886765 -0.013748    2.02270853]
# [0.07665001 0.00888425 2.03884091]
# [0.13133204 0.07851118 2.05499305]
# [0.13305259 0.16709811 2.07116499]
# [0.08103205 0.23891083 2.08735675]
# [-0.00381388  0.2649299   2.10356837]
# [-0.08728356  0.23457729  2.11979989]
# [-0.13567608  0.16001653  2.13605133]
# [-0.12939784  0.07127859  2.15232272]
# [-0.07089565  0.00416635  2.1686141 ]
# [ 0.0162957  -0.01419058  2.1849255 ]
# [0.09702105 0.02369737 2.20125695]
# [0.13867919 0.1026244  2.21760849]
# [0.12438882 0.19079178 2.23398015]
# [0.0598292  0.252619   2.25037196]
# [-0.02901629  0.26310245  2.26678395]
# [-0.10631763  0.21792695  2.28321616]
# [-0.14084771  0.13524126  2.29966862]
# [-0.11859688  0.04836721  2.31614136]
# [-0.04845676 -0.0076287   2.33263442]
# [ 0.04133258 -0.01008963  2.34914783]
# [0.11455259 0.04206438 2.36568162]
# [0.14161569 0.12786563 2.38223582]
# [0.11152122 0.21272829 2.39881047]
# [0.03632672 0.26238955 2.4154056 ]
# [-0.05368275  0.25674295  2.43202125]
# [-0.12219194  0.1979787   2.44865745]
# [-0.14150709  0.10973552  2.46531422]
# [-0.10375053  0.02759182  2.48199162]
# [-0.02407315 -0.01527891  2.49868966]
# [ 6.54250581e-02 -1.50498046e-03  2.51540839e+00]
# [0.12862716 0.06344451 2.53214784]
# [0.13997412 0.15343065 2.54890803]
# [0.09480076 0.2321642  2.56568901]
# [0.01125308 0.26784001 2.58249081]
# [-0.07700069  0.24598488  2.59931347]
# [-0.13433772  0.17532891  2.61615701]
# [-0.13755923  0.0843186   2.63302147]
# [-0.08527667  0.00966429  2.64990689]
# [ 1.49226250e-03 -1.84674116e-02  2.66681330e+00]
# [0.08777259 0.01135673 2.68374074]
# [0.1387297  0.08719014 2.70068923]
# [0.13373328 0.17849161 2.71765882]
# [0.07470943 0.24842531 2.73464954]
# [-0.01460024  0.2687222   2.75166142]
# [-0.09818819  0.23110696  2.7686945 ]
# [-0.14229822  0.15067156  2.78574881]
# [-0.12905745  0.05982027  2.80282439]
# [-0.06371803 -0.00478458  2.81992127]
# [ 0.02742565 -0.01701729  2.8370395 ]
# [0.10761831 0.02814635 2.85417909]
# [0.14446593 0.11256617 2.8713401 ]
# [0.12302121 0.20222353 2.88852255]
# [0.05184676 0.26092963 2.90572648]
# [-0.04040348  0.26493247  2.92295192]
# [-0.1165198   0.21252651  2.94019891]
# [-0.14574533  0.1247773   2.95746749]
# [-0.11620409  0.03705401  2.9747577 ]
# [-0.03972654 -0.01522676  2.99206956]
# [ 0.05288788 -0.0108996   3.00940311]
# [0.12427433 0.04838125 3.02675839]
# [0.14557711 0.13877237 3.04413544]
# [0.10811349 0.2238311  3.06153429]
# [0.02691227 0.26920784 3.07895498]
# [-0.06531487  0.25651745  3.09639754]
# [-0.13135105  0.1907881   3.11386201]
# [-0.14449236  0.09846966  3.13134843]
# [-0.09934633  0.01679033  3.14885683]
# [-0.01404402 -0.02125589  3.16638725]
# [ 7.70413408e-02 -2.36757519e-04  3.18393973e+00]
# [0.1371452  0.07145879 3.2015143 ]
# [0.14195072 0.16496836 3.21911099]
# [0.08942671 0.24257505 3.23672986]
# [6.84381936e-04 2.72920335e-01 3.25437092e+00]
# [-0.08850777  0.24367496  3.27203423]
# [-0.14214072  0.16654803  3.28971982]
# [-0.13850245  0.07259924  3.30742771]
# [-7.89673735e-02 -2.68941359e-04  3.32515796e+00]
# [ 0.01252047 -0.02260244  3.3429106 ]
# [0.09907716 0.01469895 3.36068566]
# [0.14574875 0.0966739  3.37848319]
# [0.13362645 0.19030018 3.39630322]
# [0.06750728 0.257797   3.41414578]
# [-0.02600351  0.27187042  3.43201092]
# [-0.10919777  0.22675015  3.44989868]
# [-0.14847008  0.14055484  3.46780909]
# [-0.12789218  0.04801646  3.48574218]
# [-0.05567295 -0.01351458  3.50369801]
# [ 0.03911578 -0.01914473  3.5216766 ]
# [0.11824194 0.03349174 3.53967799]
# [0.1497336  0.12324027 3.55770222]
# [0.12079749 0.21392782 3.57574934]
# [0.04301585 0.26894223 3.59381937]
# [-0.05228922  0.26601305  3.61191236]
# [-0.12666883  0.20622667  3.63002834]
# [-0.15005854  0.11362653  3.64816736]
# [-0.11293038  0.02554402  3.66632945]
# [-0.0301737  -0.0224513   3.68451465]
# [ 0.06487558 -0.01091535  3.70272301]
# [0.13386312 0.05559343 3.72095455]
# [0.1488928  0.15031457 3.73920932]
# [0.10380676 0.2350527  3.75748735]
# [0.01670772 0.27557936 3.77578869]
# [-0.07730927  0.2554588   3.79411338]
# [-0.14029768  0.18271332  3.81246145]
# [-0.14677505  0.08662517  3.83083295]
# [-0.09403194  0.00594971  3.84922791]
# [-3.26385924e-03 -2.67156839e-02  3.86764638e+00]
# [8.89462584e-02 1.89736212e-03 3.88608838e+00]
# [0.14537219 0.08033905 3.90455397]
# [0.14317289 0.17702282 3.92304319]
# [0.08313831 0.25294432 3.94155606]
# [-0.01059005  0.27741648  3.96009264]
# [-0.1002269   0.2404729   3.97865296]
# [-0.14957562  0.15692633  3.99723706]
# [-0.13864482  0.06042966  4.01584498]
# [-0.07174673 -0.01007945  4.03447677]
# [ 0.02420313 -0.02609024  4.05313246]
# [0.11051482 0.01895281 4.0718121 ]
# [0.15232484 0.10696646 4.09051572]
# [0.13267824 0.20248829 4.10924336]
# [0.05940397 0.26696506 4.12799507]
# [-0.03800433  0.27431287  4.14677089]
# [-0.12025967  0.2214692   4.16557086]
# [-0.15412691  0.12966796  4.18439501]
# [-0.1258512   0.03590744  4.2032434 ]
# [-0.04674406 -0.02196086  4.22211605]
# [ 0.05134134 -0.02051286  4.24101302]
# [0.12883598 0.03976664 4.25993434]
# [0.15441754 0.13463945 4.27888006]
# [0.1176703  0.2258599  4.29785021]
# [0.03332559 0.27659249 4.31684484]
# [-0.06464347  0.26628622  4.33586399]
# [-0.13670581  0.19899922  4.3549077 ]
# [-0.15372325  0.10180186  4.37397602]
# [-0.1087323   0.01388619  4.39306898]
# [-0.01979294 -0.02923701  4.41218663]
# [ 0.07726058 -0.0100815   4.43132901]
# [0.14325751 0.06372406 4.45049616]
# [0.15149969 0.1624737  4.46968812]
# [0.09856178 0.2463403  4.48890494]
# [0.00571351 0.28143828 4.50814666]
# [-0.08962594  0.25351462  4.52741332]
# [-0.14896831  0.17373659  4.54670497]
# [-0.14829365  0.07422609  4.56602164]
# [-0.08777267 -0.00487376  4.58536339]
# [ 0.00826117 -0.03159243  4.60473024]
# [0.1010952  0.00494632 4.62412226]
# [0.15324295 0.09009755 4.64353947]
# [0.14358116 0.18956457 4.66298192]
# [0.07590577 0.26321263 4.68244966]
# [-0.02255827  0.28126303  4.70194273]
# [-0.11210913  0.2363336   4.72146117]
# [-0.15657614  0.14645725  4.74100503]
# [-0.13792941  0.04784453  4.76057434]
# [-0.06359009 -0.01970522  4.78016916]
# [ 0.03652258 -0.02886638  4.79978953]
# [0.12203262 0.02415918 4.81943549]
# [0.15839105 0.11806862 4.83910708]
# [0.13083465 0.21501625 4.85880436]
# [0.05038023 0.27586522 4.87852736]
# [-0.05057939  0.27598659  4.89827612]
# [-0.13131734  0.2152278   4.9180507 ]
# [-0.15920164  0.11801599  4.93785114]
# [-0.12288394  0.02353766  4.95767747]
# [-0.03691769 -0.03005742  4.97752976]
# [ 0.0640735  -0.02106068  4.99740803]
# [0.13934064 0.04700246 5.01731234]
# [0.15845102 0.14675281 5.03724273]
# [0.11359289 0.23797086 5.05719925]
# [0.02276806 0.28381316 5.07718194]
# [-0.07743205  0.26569343  5.09719085]
# [-0.14656814  0.19081792  5.11722602]
# [-0.15667362  0.08932005  5.13728749]
# [-1.03567275e-01  2.13355409e-03  5.15737532e+00]
# [-0.00858222 -0.03551585  5.17748955]
# [ 0.09000353 -0.00834242  5.19763023]
# [0.15239253 0.07279391 5.21779739]
# [0.15333334 0.17522725 5.23799109]
# [0.09234058 0.25763707 5.25821137]
# [-0.0060665   0.2867163   5.27845828]
# [-0.10222066  0.25063265  5.29873187]
# [-0.15729609  0.16384276  5.31903218]
# [-0.1489856   0.06130058  5.33935925]
# [-0.08053548 -0.01561988  5.35971314]
# [ 0.02052124 -0.03581809  5.3800939 ]
# [0.11343931 0.00895859 5.40050155]
# [0.16068926 0.10074361 5.42093617]
# [0.14311535 0.20255998 5.44139778]
# [0.06770124 0.27331686 5.46188645]
# [-0.03520451  0.28439273  5.48240221]
# [-0.12410134  0.23121277  5.50294511]
# [-0.16307313  0.13513739  5.52351521]
# [-0.13629888  0.03488279  5.54411254]
# [-0.05447507 -0.02908059  5.56473716]
# [ 0.04945715 -0.0308649   5.58538911]
# [0.13357351 0.03035775 5.60606844]
# [0.16387784 0.12997776 5.6267752 ]
# [0.12804169 0.22784007 5.64750944]
# [0.0404194 0.2844298 5.6682712]
# [-0.06370126  0.27682743  5.68906054]
# [-0.1423102   0.20799121  5.7098775 ]
# [-0.16362487  0.10560762  5.73072213]
# [-0.11894016  0.01095586  5.75159448]
# [-0.02618305 -0.03773502  5.77249459]
# [ 0.07727918 -0.02072633  5.79342252]
# [0.14969221 0.05522871 5.81437832]
# [0.16176535 0.15956557 5.83536202]
# [0.10851923 0.25020751 5.8563737 ]
# [0.01133849 0.29053398 5.87741338]
# [-0.09061644  0.26417566  5.89848112]
# [-0.15618948  0.18165876  5.91957698]
# [-0.15884213  0.07620187  5.940701  ]
# [-0.09739386 -0.00965661  5.96185322]
# [ 3.45711897e-03 -4.12170715e-02  5.98303371e+00]
# [ 1.03060729e-01 -5.64233663e-03  6.00424250e+00]
# [0.16119967 0.08282124 6.02547965]
# [0.15432795 0.18854853 6.04674521]
# [0.08510665 0.26888206 6.06803923]
# [-0.01862478  0.29134269  6.08936176]
# [-0.11504479  0.24676087  6.11071285]
# [-0.1652108   0.15301953  6.13209255]
# [-0.14878736  0.0478811   6.15350091]
# [-0.0722891  -0.02622443  6.17493798]
# [ 0.03350264 -0.03932249  6.19640382]
# [0.12592537 0.01398202 6.21789847]
# [0.16763974 0.11228343 6.23942198]
# [0.14171466 0.21597099 6.2609744 ]
# [0.05849903 0.28318995 6.2825558 ]
# [-0.04850893  0.28673652  6.30416621]
# [-0.13614607  0.22506716  6.32580569]
# [-0.16899459  0.12296676  6.34747429]
# [-0.13369567  0.02158784  6.36917206]
# [-0.04438181 -0.03813619  6.39089906]
# [ 0.06298097 -0.03201837  6.41265533]
# [0.14507619 0.03758684 6.43444093]
# [0.16871312 0.14268756 6.45625592]
# [0.12424551 0.24091129 6.47810033]
# [0.0295076  0.29258762 6.49997423]
# [-0.07733813  0.27677011  6.52187767]
# [-0.15317349  0.19972637  6.54381069]
# [-0.16732497  0.09245543  6.56577336]
# [-1.13970175e-01 -1.78473466e-03  6.58776573e+00]
# [-0.01453246 -0.04492118  6.60978784]
# [ 0.09092086 -0.01944724  6.63183976]
# [0.15982301 0.06447282 6.65392153]
# [0.16428986 0.17305889 6.67603321]
# [0.10240416 0.26251221 6.69817485]
# [-9.64491553e-04  2.96681670e-01  6.72034650e+00]
# [-0.10415362  0.26167348  6.74254823]
# [-0.16549962  0.17150018  6.76478007]
# [-0.16015968  0.06247234  6.7870421 ]
# [-0.09017188 -0.02142267  6.80933435]
# [ 0.01632007 -0.04626717  6.83165688]
# [ 1.16383909e-01 -1.92552029e-03  6.85400976e+00]
# [0.16960675 0.09382153 6.87639303]
# [0.15441651 0.20240646 6.89880675]
# [0.07682512 0.28001003 6.92125096]
# [-0.03194992  0.29524428  6.94372574]
# [-0.12804514  0.24184765  6.96623113]
# [-0.17263884  0.14125768  6.98876718]
# [-0.14763452  0.03400462  7.01133396]
# [-0.0630043  -0.03661905  7.03393151]
# [ 0.04718757 -0.04203335  7.05655989]
# [0.13849562 0.02006367 7.07921916]
# [0.17401985 0.12471983 7.10190938]
# [0.13931781 0.22975498 7.1246306 ]
# [0.04827581 0.2927609  7.14738286]
# [-0.0624474   0.28822356  7.17016625]
# [-0.14818135  0.21785466  7.19298079]
# [-0.17426562  0.10994903  7.21582656]
# [-0.13006213  0.00800771  7.23870361]
# [-0.03329312 -0.04679888  7.261612  ]
# [ 0.0770637  -0.03225795  7.28455178]
# [0.15647493 0.04588321 7.30752301]
# [0.17282221 0.15618785 7.33052574]
# [0.11939253 0.25417677 7.35356004]
# [0.01763401 0.30026392 7.37662595]
# [-0.09145364  0.27574833  7.39972355]
# [-0.16383823  0.1904022   7.42285287]
# [-0.17022801  0.07857614  7.446014  ]
# [-0.10792494 -0.01462624  7.46920697]
# [-1.96158425e-03 -5.15400780e-02  7.49243184e+00]
# [ 0.10495634 -0.01716017  7.51568869]
# [0.1696612  0.07475995 7.53897755]
# [0.16595198 0.18720961 7.5622985 ]
# [0.09520363 0.27482274 7.58565159]
# [-0.01413864  0.30217994  7.60903687]
# [-0.11799582  0.25812725  7.63245441]
# [-0.17442446  0.16032325  7.65590427]
# [-0.16055559  0.04816098  7.6793865 ]
# [-0.08186261 -0.03309844  7.70290117]
# [ 0.02999773 -0.05058993  7.72644832]
# [1.29920038e-01 2.86362116e-03 7.75002803e+00]
# [0.17753789 0.1058073  7.77364035]
# [0.1535308  0.21676532 7.79728533]
# [0.06746297 0.29095135 7.82096305]
# [-0.04602637  0.29834551  7.84467355]
# [-0.14116377  0.23584194  7.86841691]
# [-0.17950309  0.12855128  7.89219317]
# [-0.14546186  0.01971284  7.9160024 ]
# [-0.05265408 -0.04673111  7.93984466]
# [ 0.06155388 -0.04387635  7.96372001]
# [0.15108757 0.02724963 7.98762851]
# [0.17975186 0.13805204 8.01157022]
# [0.13586311 0.24386449 8.03554521]
# [0.03701084 0.30195462 8.05955352]
# [-0.07699128  0.28878132  8.08359523]
# [-0.1601406   0.20953454  8.10767039]
# [-0.17880844  0.09609175  8.13177907]
# [-1.25340574e-01 -5.80471591e-03  8.15592133e+00]
# [-0.02119477 -0.05499164  8.18009723]
# [ 0.09167034 -0.03151348  8.20430682]
# [0.16769948 0.05528188 8.22855018]
# [0.17612783 0.1704643  8.25282737]
# [0.1134296  0.26757853 8.27713844]
# [4.79106642e-03 3.07380304e-01 8.30148346e+00]
# [-0.10600662  0.27369488  8.32586249]
# [-0.17423097  0.17998975  8.3502756 ]
# [-0.17225785  0.06399081  8.37472285]
# [-0.10075626 -0.02750594  8.39920429]
# [ 0.01153034 -0.05751254  8.42372   ]
# [ 0.11933854 -0.01380136  8.44827003]
# [0.17913073 0.0861127  8.47285446]
# [0.16667728 0.20198998 8.49747333]
# [0.08687482 0.28707208 8.52212672]
# [-0.02817781  0.30694941  8.5468147 ]
# [-0.13209033  0.25347719  8.57153732]
# [-0.18288584  0.14811193  8.59629464]
# [-0.15995772  0.03330205  8.62108674]
# [-0.07242898 -0.04461308  8.64591368]
# [ 0.04447707 -0.05410636  8.67077551]
# [0.14361111 0.00878038 8.69567232]
# [0.1849134  0.11878781 8.72060415]
# [0.15160152 0.23158454 8.74557108]
# [0.05698922 0.30163181 8.77057317]
# [-0.0608342   0.30056839  8.79561048]
# [-0.15433775  0.22869339  8.82068309]
# [-0.18572294  0.11489798  8.84579106]
# [-1.42203491e-01  5.05245720e-03  8.87093444e+00]
# [-0.04121385 -0.05648359  8.89611332]
# [ 0.07657483 -0.04477509  8.92132775]
# [0.16363381 0.03558488 8.9465778 ]
# [0.18475479 0.15227541 8.97186353]
# [0.1312886  0.25824704 8.99718502]
# [0.02468621 0.31069181 9.02254233]
# [-0.09210712  0.2883356   9.04793553]
# [-0.17195238  0.20006761  9.07336468]
# [-0.18254232  0.0814066   9.09882985]
# [-0.11947352 -0.01979145  9.1243311 ]
# [-8.07568782e-03 -6.26334814e-02  9.14986852e+00]
# [ 0.10676094 -0.02971354  9.17544215]
# [0.17867489 0.0658159  9.20105208]
# [0.17855014 0.18549818 9.22669836]
# [0.10630415 0.28105349 9.25238107]
# [-9.02527431e-03  3.13854688e-01  9.27810027e+00]
# [-0.12095084  0.27054166  9.30385604]
# [-0.18427377  0.16846241  9.32964843]
# [-0.17333614  0.04872515  9.35547753]
# [-0.09241696 -0.04035609  9.38134339]
# [ 0.02594023 -0.06275598  9.40724609]
# [ 1.34015220e-01 -9.30663361e-03  9.43318570e+00]
# [0.18815117 0.09855094 9.45916228]
# [0.16638948 0.21736747 9.48517591]
# [0.07737634 0.29918825 9.51122665]
# [-0.04307175  0.3109076   9.53731458]
# [-0.14637925  0.24766353  9.56343975]
# [-0.19080144  0.1348533   9.58960226]
# [-0.15829248  0.0179348   9.61580216]
# [-0.0618358  -0.05589088  9.64203952]
# [ 0.05974061 -0.05673473  9.66831442]
# [0.15739393 0.01587961 9.69462692]
# [0.19164971 0.13276886 9.7209771 ]
# [0.14855836 0.24681838 9.74736503]
# [0.0453752  0.3119725  9.77379077]
# [-0.07634881  0.30183254  9.80025441]
# [-0.167499    0.22035254  9.82675601]
# [-0.19121415  0.10029923  9.85329564]
# [-0.13779293 -0.00992463  9.87987338]
# [-0.02866173 -0.06579493  9.9064893 ]
# [ 0.09221878 -0.04465117  9.93314346]
# [0.17606183 0.04511305 9.95983595]
# [0.18894438 0.16738115 9.98656683]
# [ 0.12553219  0.27284483 10.01333618]
# [ 0.01128708  0.31888886 10.04014407]
# [-0.10775644  0.28681061 10.06699057]
# [-0.18354024  0.18941645 10.09387575]
# [-0.1853836   0.06590971 10.1207997 ]
# [-0.11240377 -0.03388922 10.14776248]
# [ 6.07172608e-03 -6.96393331e-02  1.01747642e+01]
# [ 0.12229034 -0.02678553 10.20180484]
# [ 0.1893213   0.07751611 10.22888456]
# [ 0.18000671  0.20126607 10.25600342]
# [ 0.09796438  0.29453326 10.28316147]
# [-0.02381525  0.31960117 10.31035881]
# [-0.13623476  0.26621986 10.33759549]
# [-0.19388392  0.1557962  10.36487161]
# [-0.17338229  0.03280978 10.39218723]
# [-0.08286106 -0.05310366 10.41954243]
# [ 0.04126085 -0.06718429 10.44693728]
# [ 1.48928762e-01 -3.61148645e-03  1.04743719e+01]
# [ 0.19663758  0.11209153 10.50184624]
# [ 0.16501052  0.23330437 10.52936051]
# [ 0.06666847  0.31109409 10.55691473]
# [-0.05880574  0.31396887 10.58450899]
# [-0.16079923  0.24062667 10.61214336]
# [-0.19808472  0.12053785 10.63981792]
# [-1.55484909e-01  2.10375539e-03  1.06675327e+01]
# [-0.05004996 -0.06685107 10.6952879 ]
# [ 0.07576619 -0.0583905  10.72308348]
# [ 0.17119985  0.02421554 10.75091955]
# [ 0.19765923  0.14775245 10.7787962 ]
# [ 0.14433007  0.26241572 10.8067135 ]
# [ 0.03259473  0.32188962 10.83467153]
# [-0.09254065  0.30205518 10.86267037]
# [-0.18057403  0.210771   10.89071009]
# [-0.19588878  0.08476062 10.91879078]
# [-0.13216323 -0.02516099 10.94691251]
# [-0.01497878 -0.07457889 10.97507536]
# [ 0.10844895 -0.04342421 11.00327941]
# [ 0.18829378  0.05587626 11.03152475]
# [ 0.19223299  0.18335606 11.05981144]
# [ 0.11853177  0.28759451 11.08813958]
# [-3.19807582e-03  3.26457689e-01  1.11165092e+01]
# [-0.12389536  0.28412898 11.14492049]
# [-0.19482252  0.1775456  11.17337342]
# [-0.1872456   0.04962193 11.20186811]
# [-0.10407458 -0.04802912 11.23040465]
# [ 0.02125136 -0.07591993 11.2589831 ]
# [ 0.13820788 -0.02265571 11.28760356]
# [ 0.19955379  0.09041097 11.31626611]
# [ 0.18041249  0.21773956 11.34497082]
# [ 0.08835939  0.3079439  11.37371777]
# [-0.039575    0.32452996 11.40250706]
# [-0.15180119  0.26065997 11.43133876]
# [-0.20297387  0.14196999 11.46021294]
# [-0.17231356  0.01628056 11.48912971]
# [-0.07204399 -0.06567012 11.51808913]
# [ 0.05748055 -0.07070783 11.5470913 ]
# [1.64015841e-01 3.34875431e-03 1.15761363e+01]
# [ 0.20450038  0.12674804 11.60522418]
# [ 0.16246055  0.24975758 11.63435506]
# [ 0.05471334  0.32270702 11.66352902]
# [-0.07536032  0.31604438 11.69274614]
# [-0.1752812   0.23230726 11.7220065 ]
# [-0.20464468  0.10515975 11.75131018]
# [-0.15145874 -0.01414094 11.78065727]
# [-0.03704065 -0.07740762 11.81004786]
# [ 0.09252661 -0.05898633 11.83948203]
# [ 0.18495449  0.03384165 11.86895986]
# [ 0.20285031  0.16373656 11.89848145]
# [ 0.13884457  0.2783197  11.92804686]
# [ 0.01862441  0.33129427 11.9576562 ]
# [-0.10937489  0.30115113 11.98730955]
# [-0.19348365  0.19990162 12.01700699]
# [-0.19965512  0.06829215 12.0467486 ]
# [-0.12524707 -0.04059338 12.07653448]
# [-1.49246899e-04 -8.27443387e-02  1.21063647e+01]
# [ 0.12522301 -0.04101185 12.13623939]
# [ 0.20024622  0.06791488 12.16615859]
# [ 0.19452956  0.20018214 12.1961224 ]
# [ 0.11022536  0.30242686 12.22613091]
# [-0.01877712  0.3333056  12.25618421]
# [-0.14047436  0.28021183 12.28628239]
# [-0.20571208  0.16442184 12.31642553]
# [-0.18803862  0.03256917 12.34661372]
# [-0.09442981 -0.06213641 12.37684705]
# [ 0.03746307 -0.08138168 12.40712562]
# [ 0.15445707 -0.01724934 12.4374495 ]
# [ 0.20928215  0.10452622 12.46781879]
# [ 0.17967982  0.23488489 12.49823358]
# [ 0.07743941  0.32120559 12.52869395]
# [-0.05629628  0.32854726 12.5592    ]
# [-0.16758704  0.25379197 12.58975182]
# [-0.21145094  0.12696579 12.6203495 ]
# [-1.70044987e-01 -8.21092616e-04  1.26509931e+01]
# [-0.05992275 -0.07797117 12.68168278]
# [ 0.07458294 -0.0732333  12.71241857]
# [1.79207126e-01 1.16388233e-02 1.27432006e+01]
# [ 0.21164511  0.14253049 12.77402891]
# [ 0.15865802  0.26667821 12.80490363]
# [ 0.04147517  0.33393884 12.83582485]
# [-0.09271096  0.31704204 12.86679266]
# [-0.18975005  0.22264644 12.89780715]
# [-0.21038581  0.08871713 12.92886841]
# [-0.14613646 -0.03074322 12.95997654]
# [-0.02277968 -0.08746899 12.99113162]
# [ 0.10998928 -0.058432   13.02233375]
# [ 0.19857746  0.04481044 13.05358303]
# [ 0.20712699  0.18071475 13.08487955]
# [ 0.132029    0.29446739 13.11622339]
# [3.44389950e-03 3.40092244e-01 1.31476147e+01]
# [-0.12681103  0.29903278 13.17905346]
# [-0.20614273  0.18769875 13.21053987]
# [-0.20241758  0.05090856 13.24207399]
# [-0.11697688 -0.05615241 13.27365591]
# [ 0.0158391  -0.09019507 13.30528573]
# [ 0.14249281 -0.03732978 13.33696355]
# [ 0.21182984  0.08126733 13.36868946]
# [ 0.19573955  0.21783633 13.40046355]
# [ 0.10055122  0.31726645 13.43228593]
# [-0.03545397  0.3393351  13.46415669]
# [-0.15743784  0.27497883 13.49607592]
# [-0.21611607  0.15001439 13.52804373]
# [-0.18766988  0.01478275 13.5600602 ]
# [-0.08341414 -0.07613013 13.59212545]
# [ 0.05470235 -0.08592651 13.62423955]
# [ 1.70975214e-01 -1.04906722e-02  1.36564026e+01]
# [ 0.21841062  0.11988467 13.68861476]
# [ 0.17771839  0.25266262 13.72087605]
# [ 0.06515597  0.33423241 13.7531866 ]
# [-0.07396607  0.33155513 13.78554651]
# [-0.1835229   0.24554537 13.81795587]
# [-0.21921717  0.11076903 13.85041479]
# [-0.16648946 -0.0184478  13.88292336]
# [-0.04645621 -0.08991646 13.91548169]
# [ 0.09254647 -0.07466362 13.94808987]
# [ 0.19442693  0.02132337 13.98074801]
# [ 0.21797231  0.15944498 14.0134562 ]
# [ 0.1535197   0.28401123 14.04621455]
# [ 0.02692055  0.34469537 14.07902316]
# [-0.11082768  0.31686638 14.11188212]
# [-0.20412431  0.21158593 14.14479155]
# [-0.21520783  0.0712125  14.17775153]
# [-0.13943937 -0.0476407  14.21076218]
# [-7.24167653e-03 -9.69378715e-02  1.42438236e+01]
# [ 0.12811588 -0.05663444 14.27693589]
# [ 0.21198202  0.05717328 14.31009914]
# [ 0.21038899  0.19867584 14.34331347]
# [ 0.12380988  0.31078942 14.37657898]
# [-1.29638018e-02  3.48183794e-01  1.44098958e+01]
# [-0.14480259  0.29561012 14.44326395]
# [-0.21845985  0.17411838 14.47668362]
# [-0.20407655  0.03262976 14.51015488]
# [-0.10728498 -0.07176218 14.54367784]
# [ 0.03299467 -0.09682961 14.5772526 ]
# [ 0.16020393 -0.03229178 14.61087927]
# [ 0.22294918  0.09596979 14.64455795]
# [ 0.1957648   0.23629006 14.67828876]
# [ 0.08944807  0.33203133 14.71207179]
# [-0.05322829  0.34444371 14.74590715]
# [-0.17472378  0.26834821 14.77979495]
# [-0.22593563  0.13429524 14.81373529]
# [-1.86043421e-01 -3.70017867e-03  1.48477283e+01]
# [-0.07097318 -0.08992279 14.88177404]
# [ 0.07295997 -0.08945168 14.91587266]
# [ 1.87693048e-01 -2.30311867e-03  1.49500243e+01]
# [ 0.22683766  0.13650585 14.98422894]
# [ 0.1744352   0.27102721 15.01848681]
# [ 0.05146213  0.34693189 15.05279798]
# [-0.09256621  0.33345135 15.08716256]
# [-0.19953268  0.23584935 15.12158065]
# [-0.22616904  0.09336891 15.15605237]
# [-0.16155767 -0.03654584 15.19057783]
# [-0.0316053  -0.10140921 15.22515714]
# [ 0.1113441  -0.07489789 15.2597904 ]
# [ 0.20959283  0.03246683 15.29447773]
# [ 0.22337723  0.1774934  15.32921924]
# [ 0.14696067  0.30169504 15.36401504]
# [1.10186672e-02 3.54876212e-01 1.53988652e+01]
# [-0.1296746   0.31541857 15.43376995]
# [-0.21831573  0.19906826 15.46872928]
# [-0.21900555  0.05265304 15.50374336]
# [-0.13128768 -0.06476426 15.53881228]
# [ 9.59554260e-03 -1.05710924e-01  1.55739362e+01]
# [ 0.14686189 -0.0534976  15.60911512]
# [ 0.22507473  0.07098016 15.64434927]
# [ 0.21253143  0.21760353 15.67963872]
# [ 0.11411315  0.32720958 15.71498358]
# [-0.03061201  0.35546335 15.75038398]
# [-0.16329663  0.2907907  15.78584002]
# [-0.23033698  0.15911848 15.82135182]
# [-2.04528269e-01  1.34811640e-02  1.58569195e+01]
# [-0.0961037  -0.08733984 15.89254315]
# [ 0.05132167 -0.10254093 15.92822292]
# [ 0.17829528 -0.02580971 15.96395891]
# [ 0.23350228  0.11205595 15.99975124]
# [ 0.19450347  0.25550885 16.03560003]
# [ 0.07685521  0.34663255 16.07150538]
# [-0.07209503  0.34852373 16.10746743]
# [-0.19226329  0.26023689 16.14348628]
# [-0.23506559  0.11723942 16.17956205]
# [-0.18306009 -0.02283623 16.21569486]
# [-0.05705379 -0.10341995 16.25188484]
# [ 0.09222156 -0.09184962 16.28813209]
# [2.04534286e-01 7.39071047e-03 1.63244367e+01]
# [ 0.23445563  0.15440571 16.36079892]
# [ 0.16973457  0.28992656 16.39721872]
# [ 0.03631273  0.35920474 16.43369628]
# [-0.112073    0.3341293  16.47023172]
# [-0.21553318  0.2246329  16.50682516]
# [-0.23219723  0.07475875 16.54347671]
# [-0.15515816 -0.05505471 16.58018651]
# [-1.53333268e-02 -1.12345919e-01  1.66169547e+01]
# [ 0.13094284 -0.0738312  16.6537813 ]
# [ 0.22461523  0.04513322 16.69066654]
# [ 0.22774964  0.19667297 16.72761051]
# [ 0.13889445  0.31966102 16.76461332]
# [-6.25832640e-03  3.64374365e-01  1.68016751e+01]
# [-0.14920957  0.31259623 16.838796  ]
# [-0.23222894  0.18503697 16.8759761 ]
# [-0.22166866  0.03305105 16.91321555]
# [-0.12160054 -0.0820376  16.95051446]
# [ 0.02775067 -0.11367842 16.98787297]
# [ 0.16617616 -0.04892246 17.02529119]
# [ 0.23775501  0.08627948 17.06276926]
# [ 0.21344471  0.23747594 17.10030729]
# [ 0.10286434  0.34364436 17.13790542]
# [-0.04950997  0.36181925 17.17556377]
# [-0.18223327  0.28447962 17.21328246]
# [-0.24166906  0.14265919 17.25106162]
# [-2.03664710e-01 -6.50580346e-03  1.72889014e+01]
# [-0.08336556 -0.10279517 17.32680189]
# [ 0.07081974 -0.10721623 17.36476324]
# [ 0.1966986  -0.01779355 17.40278557]
# [ 0.2433803   0.1295567  17.44086901]
# [ 0.1918499   0.27545185 17.4790137 ]
# [ 0.06271276  0.36097379 17.51721976]
# [-0.09204408  0.35146202 17.55548731]
# [-0.2099801   0.25056045 17.5938165 ]
# [-0.24339412  0.09882536 17.63220745]
# [-0.17861745 -0.0425753  17.67066028]
# [-0.04160419 -0.11651979 17.70917514]
# [ 0.11246719 -0.09300772 17.74775215]
# [ 0.22141514  0.01866888 17.78639144]
# [ 0.24115048  0.17359622 17.82509315]
# [ 0.16351805  0.30930155 17.86385741]
# [ 0.01966466  0.37094434 17.90268434]
# [-0.13245672  0.33347772 17.94157409]
# [-0.2314336   0.21182495 17.98052679]
# [-0.23718628  0.0549364  18.01954256]
# [-0.14719728 -0.07390656 18.05862155]
# [ 2.39375795e-03 -1.22615917e-01  1.80977639e+01]
# [ 0.15130323 -0.07135452 18.13696971]
# [ 0.23939689  0.059386   18.17623915]
# [ 0.23097354  0.21697588 18.21557234]
# [ 0.12923294  0.33783304 18.25496943]
# [-0.02493502  0.37307586 18.29443053]
# [-0.16938359  0.30829338 18.3339558 ]
# [-0.24576088  0.1694368  18.37354536]
# [-2.23081445e-01  1.24243921e-02  1.84131994e+01]
# [-0.11029618 -0.09937672 18.45291794]
# [ 0.04723852 -0.12072389 18.49270122]
# [ 0.18600038 -0.04280694 18.53254935]
# [ 0.24991473  0.10311776 18.57246247]
# [ 0.21301431  0.25826515 18.61244072]
# [ 0.08998866  0.3600024  18.65248423]
# [-0.0696625   0.36713336 18.69259315]
# [-0.20154519  0.27657949 18.73276761]
# [-0.25234356  0.12470318 18.77300776]
# [-0.20137338 -0.02729322 18.81331373]
# [-0.06900342 -0.11803008 18.85368567]
# [ 0.09148348 -0.11073656 18.89412372]
# [ 2.15337931e-01 -8.15141885e-03  1.89346280e+01]
# [ 0.25246715  0.14849977 18.97519871]
# [ 0.1876945   0.29607129 19.01583594]
# [ 0.04696182  0.37495081 19.05653985]
# [-0.11305975  0.35313974 19.09731058]
# [-0.22779007  0.23923329 19.13814827]
# [-0.25080232  0.07903527 19.17905308]
# [-0.17260965 -0.06285997 19.22002514]
# [-0.02457431 -0.12911266 19.2610646 ]
# [ 0.13367086 -0.0928081  19.3021716 ]
# [ 0.23824378  0.03161004 19.34334629]
# [ 0.24680138  0.19408495 19.38458882]
# [ 0.15568442  0.32908544 19.42589933]
# [1.47714361e-03 3.82036332e-01 1.94672780e+01]
# [-0.15368107  0.33138057 19.50872489]
# [-0.24713499  0.19735452 19.55024024]
# [-0.24101431  0.0339047  19.59182415]
# [-0.13757923 -0.09302569 19.63347679]
# [ 0.02160698 -0.13210093 19.67519829]
# [ 0.17237885 -0.06735454 19.71698881]
# [ 0.25383242  0.07528783 19.75884851]
# [ 0.23292687  0.23838876 19.80077752]
# [ 0.11788655  0.35612685 19.84277599]
# [-0.04503232  0.38085936 19.88484409]
# [-0.19014028  0.30240036 19.92698196]
# [-0.25880039  0.15221398 19.96918975]
# [-2.23122579e-01 -9.20295771e-03  2.00114676e+01]
# [-0.09729198 -0.11668935 20.0538157 ]
# [ 0.06806961 -0.12672376 20.09623417]
# [ 0.20626851 -0.03504584 20.13872317]
# [ 0.26143767  0.12153936 20.18128286]
# [ 0.21112055  0.27993661 20.22391339]
# [ 0.07541117  0.37618399 20.26661491]
# [-0.09106945  0.37128076 20.30938758]
# [-0.22115702  0.26699046 20.35223155]
# [-0.26224005  0.10521598 20.39514699]
# [-0.19753715 -0.04883611 20.43813404]
# [-0.05295068 -0.13293801 20.48119286]
# [ 0.11330198 -0.11297659 20.52432362]
# [2.34129016e-01 3.21037602e-03 2.05675265e+01]
# [ 0.26063896  0.16890934 20.61080154]
# [ 0.18192362  0.3173119  20.65414903]
# [ 0.02954477  0.38845095 20.69756908]
# [-0.13512025  0.35343203 20.74106185]
# [-0.24560055  0.22616864 20.7846275 ]
# [-0.25716381  0.05785556 20.82826618]
# [-0.16492743 -0.08362499 20.87197807]
# [-5.91604904e-03 -1.41080486e-01  2.09157633e+01]
# [ 0.15579991 -0.09112733 20.9596221 ]
# [ 0.25491973  0.04629324 21.00355455]
# [ 0.25128032  0.21587462 21.04756085]
# [ 0.14612965  0.34920328 21.09164116]
# [-1.82878911e-02  3.92358083e-01  2.11357956e+01]
# [-0.17570263  0.3277168  21.18002446]
# [-0.26252971  0.18115094 21.22432778]
# [-2.43552590e-01  1.16719713e-02  2.12687058e+01]
# [-0.12620606 -0.11232791 21.31315856]
# [ 0.04233397 -0.14067459 21.35768635]
# [ 0.19411566 -0.06171352 21.40228931]
# [ 0.26780766  0.09290034 21.44696759]
# [ 0.23348116  0.26089214 21.49172136]
# [ 0.10476426  0.3744495  21.53655078]
# [-0.06656706  0.38759561 21.58145603]
# [-0.21141524  0.29480365 21.62643728]
# [-0.27122757  0.13331651 21.67149468]
# [-0.22166481 -0.03180037 21.71662842]
# [-0.08250459 -0.13387433 21.76183865]
# [ 0.09024964 -0.13154688 21.80712555]
# [ 0.22690609 -0.02553081 21.8524893 ]
# [ 0.27219899  0.14158612 21.89793005]
# [ 0.20763834  0.3024486  21.94344798]
# [ 0.05905695  0.39208037 21.98904326]
# [-0.11372525  0.37412932 22.03471607]
# [-0.24098469  0.2556102  22.08046657]
# [-0.27122959  0.08416637 22.12629495]
# [-0.19203408 -0.07108176 22.17220136]
# [-0.03514154 -0.14740334 22.21818599]
# [ 0.13625821 -0.11380416 22.26424902]
# [2.52978624e-01 1.63873078e-02 2.23103906e+01]
# [ 0.26776363  0.19080564 22.35661094]
# [ 0.17441941  0.33911026 22.40291019]
# [1.04055366e-02 4.01352444e-01 2.24492885e+01]
# [-0.15819709  0.35220772 22.49574614]
# [-0.26330971  0.21127873 22.5422832 ]
# [-0.26234424  0.03527736 22.58889988]
# [-0.15545794 -0.1047965  22.63559636]
# [ 1.44163657e-02 -1.52296225e-01  2.26823728e+01]
# [ 0.17881442 -0.08783617 22.72922946]
# [ 0.2713332   0.06279781 22.77616643]
# [ 0.25445167  0.23896255 22.82318392]
# [ 0.13474682  0.3695712  22.87028211]
# [-0.03966543  0.40177809 22.91746119]
# [-0.19847017  0.32236014 22.96472132]
# [-0.27750067  0.16314406 23.01206271]
# [-2.44665207e-01 -1.17473784e-02  2.30594855e+01]
# [-0.1129777  -0.13171979 23.10698995]
# [ 0.06459848 -0.14820186 23.15457617]
# [ 0.21645132 -0.05430912 23.20224437]
# [ 0.28119901  0.11228386 23.24999474]
# [ 0.23250119  0.2844598  23.29782746]
# [ 0.08977367  0.39269854 23.34574271]
# [-0.08955144  0.39314702 23.39374068]
# [-0.23313532  0.28538581 23.44182157]
# [-0.28291312  0.11269449 23.48998555]
# [-0.21857464 -0.05532986 23.53823281]
# [-0.06585009 -0.15082083 23.58656354]
# [ 0.113779   -0.13505403 23.63497794]
# [ 2.47829566e-01 -1.41502449e-02  2.36834762e+01]
# [ 0.2820646   0.16329698 23.73205847]
# [ 0.20243694  0.32575146 23.78072498]
# [ 0.04085131  0.40757306 23.82947592]
# [-0.13761826  0.37553924 23.87831147]
# [-0.26093467  0.24233386 23.92723182]
# [-0.2791742   0.06152683 23.97623717]
# [-0.18473719 -0.09396905 24.02532771]
# [-1.55112295e-02 -1.61300652e-01  2.40745036e+01]
# [ 0.16032842 -0.11307992 24.12376514]
# [ 0.27178379  0.03147655 24.17311241]
# [ 0.27370024  0.21420437 24.22254565]
# [ 0.16505964  0.36139404 24.27206506]
# [-1.05100777e-02  4.13523791e-01  2.43216708e+01]
# [-0.1822544   0.34932891 24.37136314]
# [-0.28080579  0.19447486 24.42114222]
# [-2.66200758e-01  1.12970471e-02  2.44710082e+01]
# [-0.14408472 -0.12629133 24.52096142]
# [ 0.036466   -0.16262315 24.57100195]
# [ 0.20266647 -0.0827993  24.62113002]
# [ 0.2873643   0.08120316 24.67134584]
# [ 0.25617166  0.26334003 24.72164961]
# [ 0.1214262   0.39009564 24.77204154]
# [-0.06268692  0.41015536 24.82252181]
# [-0.22192388  0.31517882 24.87309064]
# [-0.29192064  0.1432645  24.92374823]
# [-0.24420856 -0.0363322  24.97449478]
# [-0.09779202 -0.15109788 25.0253305 ]
# [ 0.08841994 -0.15453844 25.07625559]
# [ 0.23931441 -0.0450142  25.12727025]
# [ 0.29387273  0.13349708 25.17837469]
# [ 0.2298446   0.30905814 25.22956912]
# [ 0.07282114  0.4107613  25.28085375]
# [-0.11399247  0.39736701 25.33222878]
# [-0.25521783  0.27402532 25.38369441]
# [-0.29371768  0.09030053 25.43525087]
# [-0.21371202 -0.07974537 25.48689836]
# [-0.04724418 -0.16740763 25.53863708]
# [ 0.13865208 -0.13709741 25.59046726]
# [ 2.68945394e-01 -7.89260350e-04  2.56423891e+01]
# [ 0.29089044  0.18670749 25.69440279]
# [ 0.19537967  0.34978686 25.74650858]
# [2.07200504e-02 4.22533018e-01 2.57987067e+01]
# [-0.16273008  0.37536258 25.85099727]
# [-0.28090309  0.22705416 25.90338059]
# [-0.28592614  0.03727409 25.95585685]
# [-0.17551426 -0.11742759 26.00842626]
# [ 6.00361414e-03 -1.74493957e-01  2.60610890e+01]
# [ 0.18548139 -0.11065688 26.11384542]
# [ 0.29043096  0.0485769  26.16669559]
# [ 0.2782984   0.23911614 26.21963979]
# [ 0.1537176   0.38408112 26.27267823]
# [-0.03325398  0.42482294 26.32581112]
# [-0.20724811  0.34465071 26.3790387 ]
# [-0.2979662   0.17566763 26.43236118]
# [-2.68581408e-01 -1.40830531e-02  2.64857788e+01]
# [-0.13068758 -0.14801606 26.53929171]
# [ 0.06027273 -0.17191411 26.59290021]
# [ 0.22729929 -0.07587497 26.64660449]
# [ 0.3028822   0.1015885  26.70040479]
# [ 0.2562879   0.28899163 26.75430132]
# [ 0.10605512  0.41067239 26.8082943 ]
# [-0.0873797   0.41733865 26.86238398]
# [-0.24599452  0.30603538 26.91657056]
# [-0.30565139  0.12144398 26.97085427]
# [-0.24203091 -0.06205382 27.02523535]
# [-0.08054486 -0.17034783 27.07971403]
# [ 0.11381273 -0.15953008 27.13429052]
# [ 0.26262351 -0.03369666 27.18896506]
# [ 0.30568408  0.15659663 27.24373788]
# [ 0.22536145  0.33464524 27.29860921]
# [ 0.05381193  0.42851391 27.35357928]
# [-0.13989132  0.4000994  27.40864832]
# [-0.27756959  0.26059653 27.46381657]
# [-0.30349098  0.06609024 27.51908426]
# [-0.20692995 -0.10499189 27.57445162]
# [-2.66023986e-02 -1.83502118e-01  2.76299189e+01]
# [ 0.16485656 -0.13752005 27.68548629]
# [2.90149128e-01 1.46703251e-02 2.77411541e+01]
# [ 0.29852173  0.21184927 27.79692247]
# [ 0.18632362  0.37448682 27.85279172]
# [-1.41021173e-03  4.36819759e-01  2.79087621e+01]
# [-0.18903481  0.37344269 27.96483372]
# [-0.30077484  0.2096614  28.02100696]
# [-2.91327191e-01  1.13897509e-02  2.80772820e+01]
# [-0.16422759 -0.14137676 28.13365908]
# [ 0.02946459 -0.1868358  28.19013846]
# [ 0.21167755 -0.10637993 28.24672037]
# [ 0.30879502  0.06778862 28.30340505]
# [ 0.2813976   0.26554581 28.36019275]
# [ 0.14026194  0.40707864 28.41708371]
# [-0.05787532  0.43509645 28.47407818]
# [-0.2331251   0.33802069 28.5311764 ]
# [-0.31465661  0.15476712 28.58837861]
# [-0.26932452 -0.04085394 28.64568508]
# [-0.1151426  -0.16986608 28.70309603]
# [ 0.08587268 -0.18001072 28.76061173]
# [ 0.25264636 -0.06691466 28.81823241]
# [ 0.31774418  0.12403258 28.87595834]
# [ 0.25463873  0.31589433 28.93378976]
# [ 0.08851811  0.43118566 28.99172692]
# [-0.11376639  0.42316571 29.04977007]
# [-0.27060242  0.29478635 29.10791947]
# [-0.31854273  0.09761572 29.16617538]
# [-0.23797183 -0.08887518 29.22453803]
# [-0.06113022 -0.18934331 29.2830077 ]
# [ 0.14078558 -0.16301181 29.34158463]
# [ 2.86286202e-01 -2.02192320e-02  2.94002691e+01]
# [ 0.3164764   0.18163664 29.45906132]
# [ 0.21889376  0.36117002 29.51796159]
# [ 0.03265045  0.44582029 29.57697015]
# [-0.16724251  0.40117768 29.63608728]
# [-0.30008587  0.24496952 29.69531321]
# [-0.31207092  0.04002276 29.75464823]
# [-0.19807413 -0.13100443 29.81409258]
# [-3.84043143e-03 -1.98959326e-01  2.98736465e+01]
# [ 0.19237256 -0.13615512 29.93331035]
# [ 0.31132433  0.03235    29.9930843 ]
# [ 0.30479209  0.23874938 30.05296864]
# [ 0.17511938  0.39977274 30.11296364]
# [-2.56116777e-02  4.50280339e-01  3.01730696e+01]
# [-0.21649803  0.36961371 30.23328668]
# [-0.32042243  0.19004356 30.29361526]
# [-2.95207852e-01 -1.61390075e-02  3.03540556e+01]
# [-0.15073383 -0.16572468 30.41460787]
# [ 0.05493104 -0.19816626 30.47527245]
# [ 0.238868   -0.10008536 30.53604956]
# [ 0.32673819  0.08921324 30.59693949]
# [ 0.28282639  0.29349158 30.6579425 ]
# [ 0.12455655  0.43028189 30.71905887]
# [-0.08441991  0.44417849 30.78028888]
# [-0.25982209  0.32927858 30.84163279]
# [-0.3307298   0.13168318 30.90309089]
# [-0.26825797 -0.06899903 30.96466345]
# [-0.09732204 -0.19172439 31.02635074]
# [ 0.11329756 -0.18674239 31.08815305]
# [ 0.27863024 -0.05576276 31.15007066]
# [ 0.33179452  0.14861325 31.21210385]
# [ 0.25105264  0.3440166  31.27425289]
# [ 0.06869693  0.45150684 31.33651808]
# [-0.14186413  0.42746239 31.39889968]
# [-0.29565634  0.28128205 31.46139799]
# [-0.33043144  0.07171493 31.52401329]
# [-0.23186168 -0.11674978 31.58674586]
# [-0.03944037 -0.20794487 31.64959599]
# [ 0.16934066 -0.16480714 31.71256397]
# [ 3.10197848e-01 -4.43938779e-03  3.17756501e+01]
# [ 0.32608006  0.20866813 31.83885462]
# [ 0.21027508  0.38857108 31.90217787]
# [9.24046522e-03 4.62531008e-01 3.19656201e+01]
# [-0.19603295  0.4004243  32.02918167]
# [-0.32264922  0.22701008 32.0928628 ]
# [-3.19282656e-01  1.20614749e-02  3.21566638e+01]
# [-0.18698255 -0.1577069  32.220585  ]
# [ 2.11255061e-02 -2.13620748e-01  3.22846266e+01]
# [ 0.2211716  -0.13282531 32.34878906]
# [ 0.33234137  0.0523745  32.41307253]
# [ 0.30952261  0.26742951 32.47747736]
# [ 0.1616107   0.42555415 32.54200384]
# [-0.05195486  0.46274821 32.60665227]
# [-0.24507582  0.36369986 32.67142296]
# [-0.33970479  0.16808646 32.7363162 ]
# [-0.29738642 -0.04531852 32.80133229]
# [-0.13488378 -0.19036692 32.86647155]
# [ 0.08245944 -0.20831185 32.93173426]
# [ 0.2669934  -0.0916003  32.99712075]
# [ 0.34410881  0.11295333 33.0626313 ]
# [ 0.28240162  0.32294414 33.12826623]
# [ 0.10646046  0.45357301 33.19402584]
# [-0.11292952  0.45188982 33.25991045]
# [-0.28726449  0.31825577 33.32592036]
# [-0.34602445  0.10632584 33.39205588]
# [-0.26519846 -0.09849311 33.45831732]
# [-0.0770944  -0.21346035 33.524705  ]
# [ 0.14257386 -0.19192533 33.59121923]
# [ 0.30516139 -0.04225623 33.65786031]
# [ 0.3448633   0.17540701 33.72462857]
# [ 0.24534753  0.37331726 33.79152432]
# [ 0.04647068  0.47149325 33.85854788]
# [-0.17168364  0.43004165 33.92569957]
# [-0.32105216  0.26536634 33.9929797 ]
# [-0.34114011  0.0436794  34.06038859]
# [-0.22352101 -0.14562045 34.12792656]
# [-1.53661254e-02 -2.25998627e-01  3.41955939e+01]
# [ 0.19947259 -0.16472712 34.26339105]
# [3.34240289e-01 1.37908350e-02 3.43313182e+01]
# [ 0.33431134  0.23773829 34.39937573]
# [ 0.19932992  0.41677547 34.46756397]
# [-1.65144575e-02  4.78481923e-01  3.45358832e+01]
# [-0.22624093  0.39764977 34.60433383]
# [-0.34512806  0.20657968 34.67291612]
# [-3.24937391e-01 -1.78251612e-02  3.47416304e+01]
# [-0.17348514 -0.1850108  34.81047707]
# [ 0.04837817 -0.22731304 34.87945639]
# [ 0.25121544 -0.12734201 34.94856871]
# [ 0.35305596  0.07487171 35.01781437]
# [ 0.31252078  0.29790504 35.0871937 ]
# [ 0.14563425  0.45172735 35.15670704]
# [-0.08050796  0.47404195 35.22635472]
# [-0.27471341  0.35551485 35.29613708]
# [-0.35846582  0.14367404 35.36605446]
# [-0.29766803 -0.07614761 35.4361072 ]
# [-0.11652218 -0.2151851  35.50629564]
# [ 0.11210266 -0.21708428 35.57662012]
# [ 0.29598259 -0.08074221 35.64708099]
# [ 0.36073991  0.13911209 35.71767858]
# [ 0.27992745  0.35388544 35.78841324]
# [ 0.08582786  0.47681955 35.85928532]
# [-0.14344103  0.45803655 35.93029517]
# [-0.31536496  0.30477486 36.00144312]
# [-0.36036378  0.0786058  36.07272954]
# [-0.25995068 -0.1293011  36.14415476]
# [-0.05432453 -0.23492818 36.21571915]
# [ 0.17372189 -0.19536141 36.28742305]
# [ 3.32136629e-01 -2.62242954e-02  3.63592668e+01]
# [ 0.35676502  0.20448836 36.43125081]
# [ 0.23733008  0.40374412 36.50337538]
# [2.17160960e-02 4.90986609e-01 3.65756409e+01]
# [-0.20322821  0.43070253 36.64804766]
# [-0.34667137  0.24687643 36.7205961 ]
# [-3.50475771e-01  1.34502859e-02  3.67932865e+01]
# [-0.2127599  -0.17541802 36.86611937]
# [ 1.12027696e-02 -2.43334765e-01  3.69390949e+01]
# [ 0.23116726 -0.16256939 37.01221356]
# [3.58280267e-01 3.46248714e-02 3.70854757e+01]
# [ 0.34097112  0.26888959 37.15888158]
# [ 0.18587335  0.44569716 37.2324317 ]
# [-0.04471049  0.49349273 37.30612637]
# [-0.25783471  0.39265186 37.37996598]
# [-0.3673751   0.18353558 37.45395088]
# [-0.32883123 -0.04966262 37.52808144]
# [-0.15740337 -0.21281361 37.60235805]
# [ 0.07799866 -0.23984657 37.67678107]
# [ 0.28245468 -0.1195046  37.75135088]
# [ 0.37330766  0.09997242 37.82606785]
# [ 0.31357935  0.33018394 37.90093236]
# [ 0.12701937  0.4781738  37.97594479]
# [-0.11133611  0.48396385 38.05110552]
# [-0.30534376  0.3448612  38.12641492]
# [-0.37653283  0.11668866 38.20187339]
# [-0.29584357 -0.10861633 38.2774813 ]
# [-0.0954877  -0.24004522 38.35323903]
# [ 0.14390908 -0.22427908 38.42914697]
# [ 0.32575102 -0.06731829 38.50520552]
# [ 0.37644763  0.16779286 38.58141504]
# [ 0.27519447  0.38628737 38.65777594]
# [ 0.06250809  0.49987277 38.73428861]
# [-0.17598535  0.46240885 38.81095342]
# [-0.34402178  0.28864929 38.88777079]
# [-0.37355391  0.04843505 38.96474109]
# [-0.25230643 -0.16137658 39.04186473]
# [-2.88738035e-02 -2.55965236e-01  3.91191421e+01]
# [ 0.20675456 -0.19683693 39.19657361]
# [ 3.59437496e-01 -7.48812802e-03  3.92741596e+01]
# [ 0.36729709  0.23592899 39.35190059]
# [ 0.22679492  0.43523247 39.42979688]
# [-5.69216230e-03  5.09811336e-01  3.95078489e+01]
# [-0.23649229  0.42922896 39.58605704]
# [-0.37237931  0.22564273 39.66442173]
# [-3.58228459e-01 -1.90269752e-02  3.97429434e+01]
# [-0.19937745 -0.20605958 39.82162234]
# [ 0.04037715 -0.25976583 39.90045909]
# [ 0.26440039 -0.15811714 39.97945401]
# [ 0.38216766  0.05822161 40.0586075 ]
# [ 0.34584349  0.30215869 40.13792   ]
# [ 0.16971046  0.47523536 40.2173919 ]
# [-0.07544285  0.50736528 40.29702363]
# [-0.29077108  0.38521458 40.37681559]
# [-0.38922557  0.15773098 40.45676822]
# [-0.33074382 -0.08346907 40.53688192]
# [-0.13854993 -0.24099704 40.61715711]
# [ 0.11006557 -0.25101377 40.69759423]
# [ 0.3148271  -0.10909957 40.77819369]
# [ 0.39291799  0.12780998 40.85895592]
# [ 0.3124751   0.36426536 40.93988134]
# [ 0.10558792  0.50475828 41.02097038]
# [-0.14450036  0.49229828 41.10222346]
# [-0.33688576  0.33152956 41.18364103]
# [-0.39371473  0.08701166 41.2652235 ]
# [-0.29168859 -0.14270446 41.34697131]
# [-0.07161288 -0.2647958  41.4288849 ]
# [ 0.17792139 -0.22967405 41.5109647 ]
# [ 0.35619895 -0.05112499 41.59321115]
# [ 0.39102944  0.19909841 41.67562469]
# [ 0.26797864  0.4201101  41.75820575]
# [3.63458367e-02 5.22565771e-01 4.18409548e+01]
# [-0.21058618  0.46477953 41.9238722 ]
# [-0.37311694  0.26968296 42.00695849]
# [-3.85382208e-01  1.57277719e-02  4.20902141e+01]
# [-0.2420438  -0.19466004 42.17363939]
# [-6.00471440e-04 -2.76390136e-01  4.22572349e+01]
# [ 0.24167596 -0.19612127 42.34100107]
# [3.86928255e-01 1.41393068e-02 4.24249383e+01]
# [ 0.37623814  0.2697968  42.50904711]
# [ 0.21352397  0.46770317 42.59332789]
# [-3.58809344e-02  5.27772642e-01  4.26777811e+01]
# [-0.27145999  0.42538859 42.76240729]
# [-0.3980232   0.20148887 42.84720681]
# [-0.36416956 -0.05380143 42.93218015]
# [-0.18316112 -0.23744659 43.01732778]
# [ 0.0722677  -0.27508483 43.10265017]
# [ 0.29913579 -0.15113797 43.18814776]
# [ 0.40573341  0.08474521 43.27382104]
# [ 0.34869419  0.3375751  43.35967046]
# [ 0.15063599  0.50527246 43.4456965 ]
# [-0.10880493  0.51988171 43.53189962]
# [-0.32499345  0.37510727 43.6182803 ]
# [-0.41049513  0.12901539 43.70483901]
# [-0.33043691 -0.11925382 43.79157623]
# [-0.11672853 -0.26942493 43.87849242]
# [ 0.14465391 -0.26058733 43.96558807]
# [ 0.34825573 -0.09589979 44.05286366]
# [ 0.4116884   0.1585198  44.14031966]
# [ 0.30896751  0.40013796 44.22795656]
# [ 0.08115426  0.53132671 44.31577485]
# [-0.18005643  0.49881004 44.40377501]
# [-0.36924222  0.31529807 44.49195752]
# [-0.40979998  0.05452407 44.58032287]
# [-0.28496207 -0.1783797  44.66887156]
# [-4.47242993e-02 -2.89265683e-01  4.47576041e+01]
# [ 0.21417522 -0.23302769 44.84652091]
# [ 3.87209276e-01 -3.19475356e-02  4.49356226e+01]
# [ 0.40426215  0.23313005 45.02490951]
# [ 0.25804025  0.45530016 45.11438228]
# [7.18150271e-03 5.44711242e-01 4.52040413e+01]
# [-0.24725832  0.46490244 45.29388723]
# [-0.40251393  0.24766994 45.38392043]
# [-3.95615263e-01 -1.95985420e-02  4.54741414e+01]
# [-0.22892625 -0.22907682 45.56455077]
# [ 3.06397696e-02 -2.96000515e-01  4.56551489e+01]
# [ 0.27847961 -0.19296548 45.74593644]
# [4.14453619e-01 3.88533435e-02 4.58369138e+01]
# [ 0.38334612  0.30615448 45.92808151]
# [ 0.19728571  0.50106051 46.0194401 ]
# [-0.06897782  0.54465434 46.1109901 ]
# [-0.30810309  0.41893147 46.202732  ]
# [-0.42342977  0.1742318  46.29466634]
# [-0.36805006 -0.09091514 46.38679362]
# [-0.16388625 -0.26946255 46.47911439]
# [ 0.106984   -0.28906311 46.57162915]
# [ 0.33532331 -0.14138282 46.66433845]
# [ 0.42878724  0.11436481 46.75724279]
# [ 0.34926895  0.37515944 46.85034273]
# [ 0.128434    0.53567167 46.94363878]
# [-0.14488708  0.53080236 47.03713148]
# [-0.36042964  0.36208364 47.13082136]
# [-0.43097754  0.09723521 47.22470896]
# [-0.32765282 -0.15701547 47.31879483]
# [-0.09173378 -0.29794081 47.4130795 ]
# [ 0.18183375 -0.26831818 47.5075635 ]
# [ 0.38264648 -0.07966367 47.6022474 ]
# [ 0.42939795  0.19223848 47.69713173]
# [ 0.30279737  0.43777789 47.79221703]
# [ 0.05352529  0.55770372 47.88750387]
# ...
# [ 0.24902987 -0.08503594 36.26109589]
# [ 0.26287     0.08638096 36.30605812]
# [ 0.17058106  0.23171601 36.35109647]
# [9.20229593e-03 2.92220730e-01 3.63962111e+01]
# [-0.15624548  0.24327663 36.4414022 ]
# [-0.25895692  0.10441127 36.48666992]
# [-0.2573167  -0.06849173 36.53201444]
# [-0.15176011 -0.20568147 36.57743592]
# [ 1.53112212e-02 -2.51677603e-01  3.66229345e+01]
# [ 0.1765613  -0.18770642 36.66851047]
# [ 0.26685827 -0.03936236 36.71416388]
# [ 0.24958191  0.13363129 36.75989495]
# [ 0.13147445  0.26146655 36.80570383]
# [-0.03998763  0.29241983 36.85159072]
# [-0.19567751  0.21377942 36.89755579]
# [-0.27268681  0.05706408 36.9435992 ]
# [-0.23974409 -0.11460875 36.98972113]
# [-0.10991253 -0.23194324 37.03592176]
# [ 0.06458847 -0.247436   37.08220126]
# [ 0.21338594 -0.15460752 37.12855981]
# [2.76332959e-01 9.29139041e-03 3.71749976e+01]
# [ 0.22782082  0.17822718 37.22151476]
# [ 0.08719645  0.28398749 37.26811152]
# [-0.08895205  0.2837233  37.31478804]
# [-0.22956635  0.17730869 37.3615445 ]
# [-2.77782409e-01  7.48544431e-03  3.74083811e+01]
# [-0.21392559 -0.15730377 37.45529794]
# [-0.0635378  -0.25049888 37.50229528]
# [ 0.11283803 -0.23430629 37.54937328]
# [ 0.24403082 -0.11502472 37.59653212]
# [ 0.27695974  0.05940153 37.64377197]
# [ 0.19811036  0.21865283 37.69109303]
# [ 0.03907937  0.29838306 37.73849547]
# [-0.13608612  0.26621838 37.78597947]
# [-0.25668201  0.13490168 37.83354523]
# [-0.27388593 -0.04275415 37.88119292]
# [-0.18052202 -0.19510592 37.92892273]
# [-1.40507843e-02 -2.60571217e-01  3.79767348e+01]
# [ 0.15846059 -0.21252028 38.02462944]
# [ 0.26735747 -0.07010744 38.07260672]
# [ 0.26852165  0.10936306 38.12066686]
# [ 0.1612447   0.25349471 38.16881004]
# [-1.13899244e-02  3.04002271e-01  3.82170365e+01]
# [-0.17980903  0.24028116 38.26534632]
# [-0.27598775  0.08781194 38.31373978]
# [-0.26092452 -0.09202783 38.36221704]
# [-0.14045595 -0.22667103 38.4107783 ]
# [ 3.70008467e-02 -2.61642100e-01  3.84594237e+01]
# [ 0.19990682 -0.18259686 38.50815355]
# [ 2.82440435e-01 -2.12044258e-02  3.85569679e+01]
# [ 0.25109212  0.15754011 38.60586707]
# [ 0.11826874  0.28148963 38.65485115]
# [-0.06261479  0.30046547 38.70392037]
# [-0.21861582  0.20657075 38.75307493]
# [-2.86678101e-01  3.74735361e-02  3.88023150e+01]
# [-0.23911894 -0.13870384 38.85164083]
# [-0.0948875  -0.25082804 38.90105257]
# [ 0.08798388 -0.25347498 38.95055041]
# [ 0.23572879 -0.14533159 39.00013457]
# [2.88602077e-01 3.01756090e-02 3.90498052e+01]
# [ 0.2250391   0.20231833 39.0995626 ]
# [ 0.07044978  0.30156916 39.14940687]
# [-0.11293825  0.28768272 39.19933824]
# [-0.25112794  0.16601418 39.24935691]
# [-2.88210158e-01 -1.45415211e-02  3.92994631e+01]
# [-0.20898299 -0.18119848 39.34965694]
# [-0.04518208 -0.26662092 39.39993871]
# [ 0.13723068 -0.23612891 39.45030857]
# [ 0.26462925 -0.10177698 39.50076674]
# [ 0.28544011  0.08240937 39.55131342]
# [ 0.19101969  0.2421578  39.6019488 ]
# [1.92413605e-02 3.12898661e-01 3.96526731e+01]
# [-0.16069537  0.26586323 39.70348649]
# [-0.27614084  0.11978239 39.75438922]
# [-0.28032709 -0.0665712  39.80538146]
# [-0.17131335 -0.21802855 39.85646344]
# [ 7.12938130e-03 -2.73344533e-01  3.99076354e+01]
# [ 0.18309256 -0.20996323 39.95889742]
# [ 0.28550713 -0.0532142  40.01024982]
# [ 0.27284686  0.13380909 40.06169279]
# [ 0.14996531  0.27564466 40.11322652]
# [-3.37597184e-02  3.14909640e-01  4.01648512e+01]
# [-0.20426721  0.23551529 40.21656713]
# [-0.29266699  0.06925764 40.26837442]
# [-0.26307292 -0.11691539 40.32027332]
# [-0.12717018 -0.24786176 40.37226403]
# [ 0.06039638 -0.27057317 40.42434678]
# [ 0.22399369 -0.17563274 40.47652177]
# [ 2.97497708e-01 -1.11658696e-03  4.05287892e+01]
# [ 0.25101942  0.18267591 40.58114934]
# [ 0.10305771  0.30153991 40.63360235]
# [-0.08686199  0.30732424 40.68614845]
# [-0.24213434  0.19743654 40.73878788]
# [-2.99972868e-01  1.59934552e-02  4.07915208e+01]
# [-0.23679797 -0.1638902  40.84434753]
# [-0.07784861 -0.26956344 40.89726821]
# [ 0.11289973 -0.25818074 40.95028306]
# [ 0.25848399 -0.1340731  41.00339232]
# [ 0.30000607  0.0528938  41.05659621]
# [ 0.2204602   0.22735471 41.10989494]
# [ 0.05169622  0.31882356 41.16328873]
# [-0.13833211  0.29017086 41.21677781]
# [-0.27292849  0.15269468 41.2703624 ]
# [-2.97608536e-01 -3.83319069e-02  4.13240427e+01]
# [-0.20215437 -0.20588301 41.37781899]
# [-2.48420801e-02 -2.82237872e-01  4.14316914e+01]
# [ 0.16290575 -0.23635166 41.48566029]
# [ 0.285289   -0.0864769  41.53972577]
# [ 0.29273255  0.10709543 41.59388811]
# [ 0.18196755  0.26628889 41.64814752]
# [-2.54261971e-03  3.26732786e-01  4.17025042e+01]
# [-0.18645012  0.26379025 41.75695849]
# [-0.29548037  0.10259895 41.8115105 ]
# [-0.28542875 -0.09196709 41.86616051]
# [-0.1600819  -0.24140647 41.92090874]
# [ 3.02016049e-02 -2.85262804e-01  4.19757554e+01]
# [ 0.20872228 -0.20558203 42.03070079]
# [ 3.03355283e-01 -3.42607959e-02  4.20857451e+01]
# [ 0.27568927  0.15972095 42.14088849]
# [ 0.13661664  0.29807316 42.19613129]
# [-0.05795224  0.32479258 42.25147371]
# [-0.22956564  0.2288316  42.30691598]
# [-0.30886229  0.0486632  42.36245833]
# [-0.26360469 -0.14314282 42.41810099]
# [-0.11178401 -0.26914964 42.47384421]
# [ 0.08553022 -0.27831599 42.52968823]
# [ 0.24875455 -0.16667065 42.58563327]
# [3.11889779e-01 2.09752881e-02 4.26416796e+01]
# [ 0.24920689  0.20901345 42.6978274 ]
# [ 0.08573097  0.32150262 42.75407697]
# [-0.11274841  0.31283782 42.81042852]
# [-0.26615303  0.18623859 42.86688231]
# [-3.12423765e-01 -7.43851921e-03  4.29234386e+01]
# [-0.23262568 -0.19012892 42.98009752]
# [-0.0586949  -0.28802465 43.03685945]
# [ 0.13934159 -0.26139257 43.09372457]
# [ 0.28155919 -0.12070013 43.15069314]
# [ 0.31039152  0.07749588 43.20776539]
# [ 0.2139313   0.25328379 43.26494159]
# [3.08451162e-02 3.35616580e-01 4.33222220e+01]
# [-0.16512537  0.2910258  43.37960677]
# [-0.29486382  0.1372256  43.43709626]
# [-0.30581912 -0.06392262 43.49469068]
# [-0.19329074 -0.23129141 43.55239027]
# [-2.43830719e-03 -2.97207186e-01  4.36101953e+01]
# [ 0.18984095 -0.2348126  43.66810599]
# [ 0.30589463 -0.06900832 43.72612263]
# [ 0.29867472  0.13348312 43.78424544]
# [ 0.17080993  0.29096699 43.84247469]
# [-2.63401324e-02  3.39735366e-01  4.39008106e+01]
# [-0.21331398  0.25983864 43.95925353]
# [-0.31457463  0.08324459 44.01780362]
# [-0.2890258  -0.1189513  44.07646117]
# [-0.14668981 -0.26514777 44.13522643]
# [ 0.0552208  -0.29616942 44.19409967]
# [ 0.23529935 -0.19921828 44.25308114]
# [ 3.20766131e-01 -1.31508671e-02  4.43121711e+01]
# [ 0.27688215  0.18709391 44.3713698 ]
# [ 0.12106811  0.32067595 44.43067753]
# [-0.08400914  0.33348902 44.49009452]
# [-0.25563995  0.22007527 44.54962105]
# [-3.24428884e-01  2.59435232e-02  4.46092574e+01]
# [-0.26235271 -0.17069097 44.66900377]
# [-0.09417524 -0.29041865 44.72886048]
# [ 0.11243021 -0.2847041  44.78882779]
# [ 0.27411137 -0.15556061 44.84890596]
# [ 0.32546384  0.0451442  44.90909525]
# [ 0.24548826  0.23651908 44.96939594]
# [ 0.06617577  0.34125066 45.02980829]
# [-0.14028764  0.31683656 45.09033257]
# [-0.29058052  0.17283291 45.15096905]
# [-3.23870947e-01 -3.28825389e-02  4.52117180e+01]
# [-0.22643795 -0.21737183 45.27257971]
# [-3.73240587e-02 -3.06074173e-01  4.53335544e+01]
# [ 0.1673085  -0.26293882 45.39464243]
# [ 0.30485016 -0.10507588 45.455844  ]
# [ 0.31959263  0.10402848 45.51715941]
# [ 0.2052916   0.280043   45.57858894]
# [7.80553278e-03 3.51801252e-01 4.56401329e+01]
# [-0.19330223  0.29007513 45.70179144]
# [-0.31681739  0.11947852 45.76356497]
# [-0.31267125 -0.0913462  45.82545373]
# [-0.18223592 -0.2573469  45.88745799]
# [ 2.21079223e-02 -3.11373310e-01  4.59495780e+01]
# [ 0.2180055  -0.23133983 46.01181417]
# [ 0.32631796 -0.04925224 46.07416664]
# [ 0.30309231  0.1615904  46.13663575]
# [ 0.15739655  0.31610145 46.19922177]
# [-0.05221681  0.35174328 46.261925  ]
# [-0.24124117  0.25383834 46.32474571]
# [-0.33328447  0.06161083 46.3876842 ]
# [-0.29094152 -0.14752684 46.45074076]
# [-0.13099387 -0.28914836 46.51391566]
# [ 0.08223885 -0.30589479 46.5772092 ]
# [ 0.26276305 -0.19070499 46.64062168]
# [3.37590481e-01 1.02126185e-02 4.67041534e+01]
# [ 0.27624765  0.21591571 46.76780458]
# [ 0.10318481  0.34333605 46.8315756 ]
# [-0.11196789  0.340824   46.89546671]
# [-0.28241473  0.20908376 46.95947821]
# [-3.39208445e-01  1.01398288e-03  4.70236104e+01]
# [-0.25913929 -0.19953215 47.08786359]
# [-0.07421838 -0.31153955 47.15223805]
# [ 0.14111889 -0.28955845 47.21673409]
# [ 0.2999743  -0.14214577 47.28135201]
# [ 0.33805347  0.07146151 47.3460921 ]
# [ 0.23968734  0.26514961 47.41095467]
# [4.42771636e-02 3.60643276e-01 4.74759400e+01]
# [-0.16948689  0.31913854 47.54104846]
# [-0.31531295  0.15706962 47.60628029]
# [-0.33414096 -0.06039596 47.6716358 ]
# [-0.2180614  -0.24556029 47.7371153 ]
# [-1.36326897e-02 -3.23560631e-01  4.78027191e+01]
# [ 0.19679196 -0.26263603 47.86844753]
# [ 0.32823954 -0.08705869 47.93430086]
# [ 0.32743008  0.13253427 48.00027941]
# [ 0.19437192  0.30755841 48.0663835 ]
# [-1.75133697e-02  3.67216464e-01  4.81326134e+01]
# [-0.22283828  0.28713517 48.19896952]
# [-0.338659    0.09932115 48.26545208]
# [-0.31798102 -0.12063003 48.33206142]
# [-0.16882626 -0.28396054 48.39879786]
# [ 0.04887399 -0.32456645 48.46566171]
# [ 0.24735901 -0.22575085 48.53265329]
# [ 3.46416646e-01 -2.70869549e-02  4.85997729e+01]
# [ 0.30579809  0.19142888 48.6670209 ]
# [ 0.14157055  0.34158873 48.73439757]
# [-0.08023577  0.36257916 48.80190324]
# [-0.27017531  0.24560936 48.86953824]
# [-3.51456323e-01  3.75876159e-02  4.89373029e+01]
# [-0.29098668 -0.17768918 49.0051975 ]
# [-0.11284539 -0.31329061 49.0732224 ]
# [ 0.11130383 -0.31425515 49.14137793]
# [ 0.29104114 -0.17986615 49.2096644 ]
# [3.53664429e-01 3.59269925e-02 4.92780821e+01]
# [ 0.27359594  0.24616545 49.34663148]
# [ 0.0828274   0.36592234 49.41531275]
# [-0.14186097  0.34660866 49.48412628]
# [-0.30980212  0.19568634 49.55307239]
# [-3.53027784e-01 -2.62090934e-02  4.96221514e+01]
# [-0.25377541 -0.22962894 49.69136373]
# [-0.0517847  -0.33236849 49.76070961]
# [ 0.17161258 -0.29268635 49.83018941]
# [ 0.32624024 -0.12626208 49.89980348]
# [ 0.3494773   0.09999638 49.96955214]
# [ 0.23161734  0.29485106 50.03943573]
# [1.99181733e-02 3.79524708e-01 5.01094546e+01]
# [-0.20034587  0.31954863 50.17960908]
# [-0.34023249  0.13879271 50.24989952]
# [-0.34304551 -0.0900326  50.32032626]
# [-0.2073129  -0.27462388 50.39088964]
# [ 1.24833189e-02 -3.40317300e-01  5.04615900e+01]
# [ 0.22777481 -0.26028803 50.53242769]
# [ 0.35159537 -0.06650191 50.60340306]
# [ 0.33370992  0.16305107 50.67451646]
# [ 0.18099423  0.33574337 50.74576822]
# [-4.52018428e-02  3.81685587e-01  5.08171587e+01]
# [-0.2536993   0.2820102  50.88868828]
# [-0.36024328  0.07661749 50.96035727]
# [-0.32155014 -0.15179535 51.03216604]
# [-0.15289025 -0.31102983 51.10411494]
# [ 0.07793536 -0.3366012  51.17620433]
# [ 0.27785013 -0.2178518  51.24843456]
# [ 3.66032771e-01 -2.38828923e-03  5.13208060e+01]
# [ 0.30659084  0.22300277 51.39331899]
# [ 0.12316839  0.3673109  51.4659739 ]
# [-0.11045682  0.37205006 51.53877109]
# [-0.30004799  0.23496123 51.61171092]
# [-3.68920640e-01  1.10637600e-02  5.16847938e+01]
# [-0.28895859 -0.20942515 51.75801995]
# [-0.0920901  -0.33744177 51.83138989]
# [ 0.14245922 -0.32105131 51.90490392]
# [ 0.32004834 -0.16651615 51.97856243]
# [ 0.36880786  0.06408939 52.05236576]
# [ 0.26872434  0.27781232 52.1263143 ]
# [ 0.05985228  0.38828799 52.20040842]
# [-0.17371481  0.35063893 52.27464848]
# [-0.3377003   0.17970376 52.34903486]
# [-0.36569738 -0.05580779 52.42356794]
# [-0.24605992 -0.2609328  52.49824808]
# [-2.67425088e-02 -3.52745386e-01  5.25730757e+01]
# [ 0.2039202  -0.29388029 52.64805109]
# [ 0.35279129 -0.10773811 52.72317471]
# [ 0.35953764  0.13081491 52.79844691]
# [ 0.22108017  0.32555721 52.87386807]
# [-7.01978680e-03  3.97722571e-01  5.29494386e+01]
# [-0.23285558  0.31785738 53.02515882]
# [-0.36520572  0.11784001 53.10102918]
# [-0.35038005 -0.12184184 53.17705003]
# [-0.19399901 -0.30447883 53.25322178]
# [ 4.11282957e-02 -3.56160546e-01  5.33295448e+01]
# [ 0.26022985 -0.25568499 53.40601948]
# [ 3.74769422e-01 -4.32539892e-02  5.34826462e+01]
# [ 0.33822215  0.19561081 53.55942542]
# [ 0.16497124  0.3644969  53.63635745]
# [-0.0753489   0.3950149  53.71344272]
# [-0.28583976  0.27449151 53.79068162]
# [-3.81408019e-01  5.12279597e-02  5.38680746e+01]
# [-0.32316464 -0.18485608 53.94562191]
# [-0.13424828 -0.33843695 54.0233241 ]
# [ 0.10936476 -0.34727503 54.10118151]
# [ 0.30941497 -0.20743676 54.17919456]
# [3.84991089e-01 2.49700713e-02 5.42573636e+01]
# [ 0.30525417  0.25630752 54.33568915]
# [ 0.10201961  0.39313391 54.41417151]
# [-0.14293557  0.37994597 54.49281111]
# [-0.3307771   0.22169239 54.57160838]
# [-3.85490214e-01 -1.80725888e-02  5.46505637e+01]
# [-0.28464001 -0.2427114  54.72967753]
# [-0.0685682  -0.36145224 54.80895024]
# [ 0.17574272 -0.32606722 54.88838225]
# [ 0.34968461 -0.15045934 54.96797398]
# [ 0.38282279  0.09479607 55.04772585]
# [ 0.26141638  0.31081402 55.12763827]
# [3.41116716e-02 4.10268682e-01 5.52077117e+01]
# [-0.20754862  0.35269422 55.28794644]
# [-0.36599166  0.16094792 55.36834304]
# [-0.37700972 -0.08786175 55.44890188]
# [-0.23577875 -0.29338242 55.52962337]
# [ 1.04258123e-03 -3.72492117e-01  5.56105080e+01]
# [ 0.23804192 -0.29291674 55.69155604]
# [ 0.37949284 -0.08639486 55.77276808]
# [ 0.36801886  0.16397925 55.85414448]
# [ 0.20786583  0.35718781 55.93568569]
# [-3.66564268e-02  4.15046040e-01  5.60173921e+01]
# [-0.26699682  0.31383993 56.09926423]
# [-0.3900817   0.09404313 56.18130244]
# [-0.35592228 -0.15586746 56.26350719]
# [-0.17791542 -0.33502621 56.34587891]
# [ 0.0724061  -0.37088802 56.42841804]
# [ 0.29411825 -0.24860236 56.51112503]
# [ 3.97595245e-01 -1.71586361e-02  5.65940003e+01]
# [ 0.34073936  0.23023825 56.67704435]
# [ 0.14610602  0.3937017  56.76025757]
# [-0.10804145  0.40699184 56.84364042]
# [-0.3192011   0.26435661 56.92719334]
# [-4.01972204e-01  2.30097845e-02  5.70109168e+01]
# [-0.32259361 -0.21981739 57.09481123]
# [-0.11271242 -0.36604682 57.17887709]
# [ 0.14323118 -0.35636654 57.26311484]
# [ 0.34197531 -0.19428694 57.34752493]
# [4.03097108e-01 5.51160472e-02 5.74321078e+01]
# [ 0.30155532  0.29132827 57.51686394]
# [ 0.0779469   0.41890556 57.60179378]
# [-0.17772219  0.38603816 57.6868978 ]
# [-0.36226494  0.20558952 57.77217645]
# [-4.00958266e-01 -4.99332321e-02  5.78576302e+01]
# [-0.27779805 -0.27751277 57.94325952]
# [-4.21145133e-02 -3.85153490e-01  5.80290649e+01]
# [ 0.21118494 -0.32906841 58.1150467 ]
# [ 0.3798331  -0.13148963 58.20120551]
# [ 0.39549146  0.12814157 58.28754175]
# [ 0.25144079  0.34511494 58.37405591]
# [5.45403591e-03 4.31680484e-01 5.84607485e+01]
# [-0.24337282  0.35253599 58.54761986]
# [-0.39454075  0.1392216  58.6346706 ]
# [-0.38673753 -0.12244717 58.72190116]
# [-0.22270406 -0.32690172 58.80931201]
# [ 3.17070596e-02 -3.91410467e-01  5.88969036e+01]
# [ 0.2739675  -0.28955477 58.98467654]
# [ 0.40619144 -0.06204568 59.07263118]
# [ 0.37468564  0.19954627 59.16076806]
# [ 0.19175169  0.38964651 59.24908766]
# [-0.06911185  0.43128381 59.33759047]
# [-0.30273831  0.30725475 59.42627698]
# [-0.41468981  0.0672276  59.51514768]
# [-0.35943049 -0.19214623 59.60420308]
# [-0.1588465  -0.3661497  59.69344366]
# [ 0.10641921 -0.38427667 59.78286993]
# [ 0.32938753 -0.23879983 59.87248238]
# [4.19885988e-01 1.19448472e-02 5.99622815e+01]
# [ 0.34101512  0.26694935 60.05226783]
# [ 0.12419172  0.42322202 60.14244184]
# [-0.14336321  0.41738304 60.23280404]
# [-0.3537096   0.25136825 60.32335495]
# [-4.21733834e-01 -8.18248063e-03  6.04140951e+01]
# [-0.31958768 -0.25667389 60.50502492]
# [-0.08808633 -0.39370482 60.596145  ]
# [ 0.17959853 -0.36363361 60.68745582]
# [ 0.37543632 -0.17817005 60.77895792]
# [ 0.42013489  0.08817841 60.8706518 ]
# [ 0.29524382  0.32803791 60.96253797]
# [5.07661396e-02 4.44453146e-01 6.10546170e+01]
# [-0.21485993  0.39007742 61.14688932]
# [-0.39439588  0.1864271  61.23935554]
# [-0.41509629 -0.08462896 61.33201615]
# [-0.26818303 -0.31378017 61.42487168]
# [-1.25587914e-02 -4.08355695e-01  6.15179227e+01]
# [ 0.24880769 -0.32980033 61.61116964]
# [ 0.41035781 -0.10939013 61.70461313]
# [ 0.40657426  0.16421745 61.79825366]
# [ 0.23855059  0.38064391 61.89209179]
# [-2.62754129e-02  4.52317543e-01  6.19861280e+01]
# [-0.28118717  0.34990614 62.08036295]
# [-0.4231918   0.1143184  62.17479708]
# [-0.39463167 -0.15963532 62.26943095]
# [-0.20659348 -0.36139759 62.36426512]
# [ 0.06538876 -0.40927978 62.45930013]
# [ 0.31167421 -0.28353468 62.55453653]
# [ 4.32712336e-01 -3.44964064e-02  6.26499749e+01]

# %% [markdown]
# We gaan de solenoide nu gebruiken voor onze krachtactuator. Daarvoor gaan we opnieuw de energie in het magnetisch veld berekenen, maar nu met het numerieke resultaat voor een eindige lengte solenoide. We gaan hier nu een aantal aannames maken:
# * We nemen aan het veld alleen een $z$-component heeft en niet afhangt van de afstand tot de solenoide as
# * We verwaarlozen de bijdrage aan de energie van het deel van de solenoide gevuld in lucht en integreren alleen het deel van ijzer in het $\mathbf{H}$ veld (dat mag omdat $\mu_r \gg 1$)
# * De plunjer is oneindig lang
#
# Zoals je uit je berekening voor het $\mathbf{H}$ kan zien is de energie van de plunjer in de solenoide groter dan voor de plunjer uit de solenoide. Dit komt doordat we de berekening doen met constante stroom. De verplaatsing van de plunjer geeft echter ook een veranderende flux ($d \Phi/dt$) die een tegen EMF geeft. Deze moet overwonnen worden door de stroombron die de arbeid levert. Het magneetveld verricht dus geen arbeid, dat doet de stroombron! We berekenen dit effect hier niet expliciet, maar nemen $-W$ als energie zodat de kracht de juiste kant op wijst (de solenoide in, dus een kracht in de $-z$ richting).
#
#
# **Opdracht 16**
#
# * Bereken de energie als functie van de afstand van de plunjer in de solenoide met behulp van onderstaand script

# %%
# integrate the field up to point z_p
mu_r = 50000
mu_0 = 4*np.pi * 1e-7
r_s = r_sol
L_s = L_sol

Wz=-0.5*np.pi*r_s**2*np.cumsum(np.flipud(H_ax)*mu_r*mu_0*np.flipud(H_ax))*(z_ax[1] - z_ax[0])

plt.plot(L_s/2 - z_ax, np.flipud(Wz), '-k')
plt.xlabel('Afstand van plunjer in solenoide (m)'), plt.ylabel('Energie (J)'), plt.grid()
# Out:
# (Text(0.5, 0, 'Afstand van plunjer in solenoide (m)'),
#  Text(0, 0.5, 'Energie (J)'),
#  None)

# %%
force_analytical = -mu_0*mu_r*np.pi*r_s**2*aantal_omwent**2*I**2/2/L_s**2 # Kracht uitrekenen numeriek
force_numerical=np.diff(Wz, n=1, append=[0])/(z_ax[1] - z_ax[0]) # Kracht uitrekenen

# Plotting the results
plt.plot(L_s/2 - z_ax, np.flipud(force_numerical), '-o', label='Kracht')
plt.plot(L_s/2 - z_ax, (-5*9.8)*np.ones(n_ax), '--r', label='Benodigde kracht')
plt.plot(L_s/2 - z_ax, force_analytical*np.ones(n_ax), '--g', label='Kracht oneindig lange solenoide')
plt.xlabel('Afstand van plunjer in solenoide (m)'), plt.ylabel('Kracht (N)'), plt.grid(), plt.legend()
plt.ylim([-200, 0])
# Out:
# (-200.0, 0.0)

# %% [markdown]
# ### Deel 7: Beoordeling van de criteria
# **Opdracht 17**
#
# Kijk in deze vraag terug naar de criteria die jullie voor de deuractuator hebben opgesteld. Voldoet jullie ontwerp aan alle gestelde criteria?

# %% [markdown]
# Plaats hier jullie evaluatie of de deur actuator aan de minimale kracht eis voldoet

# %% [markdown]
# **Opdracht 18**
#
# Voer opdrachten 15 en 16 uit voor jouw eigen gekozen toepassingen.

# %%
###
###Jullie code hier###
###

# %% [markdown]
# **Opdracht 19**
#
# a. Kijk terug naar de criteria die jullie hebben opgesteld in vraag 5. Hebben jullie nu genoeg informatie om te beoordelen of jullie ontwerp voldoet aan de gestelde criteria, zo nee ontwerp een simpel experiment waarmee jullie het wel zouden uit kunnen voeren.
# b. Beoordeel op basis van de criteria die jullie wel kunnen beoordelen of jullie idee voldoet aan jullie criteria.

# %% [markdown]
# Edit deze cel met jullie antwoorden op vraag 19.

# %% [markdown]
# Controleer eerst nog goed of alles klopt. **Klik boven op `Kernel -> Restart and Run all` en check of er geen errors zijn**. Zorg dat alle benodigde bestanden zijn geüpload in de juiste map en dat de afbeeldingen zichtbaar zijn in het notebook. Je kan nu jouw notebook opslaan, comitten en pushen naar de juiste branch! Maak dan de pull request aan en lever die in in brightspace.
